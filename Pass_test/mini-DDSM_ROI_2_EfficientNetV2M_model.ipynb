# %%
import cv2
import matplotlib.pyplot as plt
# import pandas as pd
import tensorflow as tf
import keras
import os
import numpy as np
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M, preprocess_input
# from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Sequential

PATH = "/mnt/d/Datasets/"
imgPATH = PATH + "mini-DDSM/MINI-DDSM-Complete-PNG-16/"
ddsm_roi_path = PATH + "mini-DDSM/ROI_2/"
vindr_roi_path = PATH+"/Vindr-Mammo/ROI/"
data_path = PATH + "mini-DDSM/fullimg/"
save_dir = "/home/jj/FYP/Models/"
combined_path = PATH + "combined/"
image_size = 300
batch_size = 16
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

os.environ['TF_ENABLE_GPU_GARBAGE_COLLECTION'] = 'false'
# Out:
# 2023-02-06 02:20:43.926524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-06 02:20:43.959877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-06 02:20:43.959916: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # load ddsm

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  ddsm_roi_path,
#   label_mode="categorical",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=None)
  
val_ds = tf.keras.utils.image_dataset_from_directory(
  ddsm_roi_path,
#   label_mode="categorical",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=None)
# Out:
# Found 2830 files belonging to 2 classes.
# Using 2264 files for training.
# Found 2830 files belonging to 2 classes.
# Using 566 files for validation.

# %% [markdown]
# # load vindr

# %%
# train_vindr = tf.keras.utils.image_dataset_from_directory(
#   vindr_roi_path+'train',
#   # data_path,
#   validation_split=0.2,
#   subset="training",
#   seed=123,
#   image_size=(image_size, image_size),
#   batch_size=None)
# val_vindr = tf.keras.utils.image_dataset_from_directory(
#   vindr_roi_path+'train',
#   # data_path,
#   validation_split=0.2,
#   subset="validation",
#   seed=123,
#   image_size=(image_size, image_size),
#   batch_size=None)

# %% [markdown]
# # combined

# %%
# train_combined = tf.keras.utils.image_dataset_from_directory(
#   combined_path+'train',
#   # data_path,
#   validation_split=0.2,
#   subset="training",
#   seed=123,
#   image_size=(image_size, image_size),
#   batch_size=1)
# val_combined = tf.keras.utils.image_dataset_from_directory(
#   combined_path+'train',
#   # data_path,
#   validation_split=0.2,
#   subset="validation",
#   seed=123,
#   image_size=(image_size, image_size),
#   batch_size=1)

# %%
preprocessing = preprocess_input
pre_trained = EfficientNetV2M(weights='imagenet', include_top=False, input_shape=(image_size,image_size,3))
pre_trained.trainable = False
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.5),fill_mode="reflect"),
  tf.keras.layers.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2),fill_mode="reflect"),
  tf.keras.layers.RandomTranslation(height_factor=(-0.1,0.1),width_factor=(-0.1,0.1),fill_mode="reflect")
  ])
#Define model architect
tfinput = Input(shape=(image_size,image_size,3))
# data_augment = data_augmentation(tfinput)
pre_process = preprocessing(tfinput)
efficientnetv2m_model=pre_trained(pre_process,training=False)
flatten = tf.keras.layers.GlobalAveragePooling2D()(efficientnetv2m_model)
# DO1 = Dropout(0.8)(flatten)
Dense1 = Dense(1024,activation = 'relu')(flatten)
x=Dropout(0.7)(Dense1)
x = Dense(512,activation='relu')(x)
DO2 = Dropout(0.7)(x)
# output = Dense(1, activation="sigmoid")(DO2)
output = Dense(1, activation="sigmoid")(DO2)
model = Model(tfinput,output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  efficientnetv2-m (Functiona  (None, 10, 10, 1280)     53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 54,987,445
# Trainable params: 1,837,057
# Non-trainable params: 53,150,388
# _________________________________________________________________

# %%
AUTOTUNE = tf.data.AUTOTUNE
def prepare(ds, shuffle=False, augment=False,batch_size=32):
  # # Resize and rescale all datasets.
  
  data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.3),fill_mode="nearest"),
  tf.keras.layers.RandomZoom(height_factor=(-0.5,0.5),width_factor=(-0.5,0.5),fill_mode="nearest"),
  tf.keras.layers.RandomTranslation(height_factor=(-0.25,0.25),width_factor=(-0.25,0.25),fill_mode="nearest")
  ])
  if shuffle:
    ds = ds.shuffle(1000)

  
  # ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    # ds = ds.map(lambda x, y: (resize_and_rescale(x), y), 
    #           num_parallel_calls=AUTOTUNE)
    ds = ds.map(lambda x, y: (data_augmentation(x,training=True),y), 
                num_parallel_calls=AUTOTUNE)
  # Batch all datasets.
  
  # print(ds)
  # Use buffered prefetching on all datasets.
  return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds_aug = prepare(train_ds,shuffle=False,augment=True,batch_size=batch_size)
val_ds_aug = prepare(val_ds,batch_size=batch_size)
# train_ds_aug = train_ds.prefetch(buffer_size=AUTOTUNE)
# val_ds_aug= val_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# for i in train_ds_aug.take(9):
#  plt.imshow(i[0])
train_ds_aug.take(9)
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>

# %% [markdown]
# # initialising

# %%
# init_lr = 1e-3
# steps = 1e3
# final_lr = 1e-4
# lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
#                                                             ,steps
#                                                             ,final_lr
#                                                             ,power=0.5)

# %%
model.compile(
    optimizer= tf.keras.optimizers.RMSprop(learning_rate=1e-3),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.FalseNegatives()]
    # ,jit_compile=True
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 10, 10, 1280)     53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 54,987,445
# Trainable params: 1,837,057
# Non-trainable params: 53,150,388
# _________________________________________________________________

# %%
#Training Dense layers to initialise the categoriser before fine tuning the CNN models
total_epochs = 10
dense_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(dense_init.history['loss'])
plt.subplot(132)
plt.plot(dense_init.history['val_loss'])
plt.subplot(133)
plt.plot(dense_init.history['val_binary_accuracy'])
# Out:
# Epoch 1/10
# 2023-02-04 01:39:43.826284: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 2023-02-04 01:39:47.607446: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.607505: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.620387: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.620426: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.669354: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.50GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.669398: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.50GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:39:47.708545: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 142/142 [==============================] - ETA: 0s - loss: 0.8315 - binary_accuracy: 0.5380 - false_positives: 512.0000 - false_negatives: 534.0000
# 2023-02-04 01:40:24.027924: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:40:24.027981: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:40:24.037783: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-04 01:40:24.037821: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Epoch 1: val_binary_accuracy improved from -inf to 0.56360, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint/cp-0001.ckpt
# 142/142 [==============================] - 66s 354ms/step - loss: 0.8315 - binary_accuracy: 0.5380 - false_positives: 512.0000 - false_negatives: 534.0000 - val_loss: 0.6778 - val_binary_accuracy: 0.5636 - val_false_positives: 236.0000 - val_false_negatives: 11.0000
# Epoch 2/10
# 142/142 [==============================] - ETA: 0s - loss: 0.7600 - binary_accuracy: 0.5508 - false_positives: 523.0000 - false_negatives: 494.0000
# Epoch 2: val_binary_accuracy did not improve from 0.56360
# 142/142 [==============================] - 26s 165ms/step - loss: 0.7600 - binary_accuracy: 0.5508 - false_positives: 523.0000 - false_negatives: 494.0000 - val_loss: 0.6869 - val_binary_accuracy: 0.5548 - val_false_positives: 236.0000 - val_false_negatives: 16.0000
# Epoch 3/10
# 142/142 [==============================] - ETA: 0s - loss: 0.7268 - binary_accuracy: 0.5605 - false_positives: 498.0000 - false_negatives: 497.0000
# Epoch 3: val_binary_accuracy improved from 0.56360 to 0.59717, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint/cp-0003.ckpt
# 142/142 [==============================] - 43s 287ms/step - loss: 0.7268 - binary_accuracy: 0.5605 - false_positives: 498.0000 - false_negatives: 497.0000 - val_loss: 0.6487 - val_binary_accuracy: 0.5972 - val_false_positives: 162.0000 - val_false_negatives: 66.0000
# Epoch 4/10
# 142/142 [==============================] - ETA: 0s - loss: 0.7134 - binary_accuracy: 0.5658 - false_positives: 471.0000 - false_negatives: 512.0000
# Epoch 4: val_binary_accuracy improved from 0.59717 to 0.61484, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint/cp-0004.ckpt
# 142/142 [==============================] - 24s 169ms/step - loss: 0.7134 - binary_accuracy: 0.5658 - false_positives: 471.0000 - false_negatives: 512.0000 - val_loss: 0.6356 - val_binary_accuracy: 0.6148 - val_false_positives: 141.0000 - val_false_negatives: 77.0000
# Epoch 5/10
# 142/142 [==============================] - ETA: 0s - loss: 0.7020 - binary_accuracy: 0.5910 - false_positives: 425.0000 - false_negatives: 501.0000
# Epoch 5: val_binary_accuracy did not improve from 0.61484
# 142/142 [==============================] - 24s 165ms/step - loss: 0.7020 - binary_accuracy: 0.5910 - false_positives: 425.0000 - false_negatives: 501.0000 - val_loss: 0.7060 - val_binary_accuracy: 0.5389 - val_false_positives: 256.0000 - val_false_negatives: 5.0000
# Epoch 6/10
# 142/142 [==============================] - ETA: 0s - loss: 0.6917 - binary_accuracy: 0.5888 - false_positives: 437.0000 - false_negatives: 494.0000
# Epoch 6: val_binary_accuracy did not improve from 0.61484
# 142/142 [==============================] - 24s 165ms/step - loss: 0.6917 - binary_accuracy: 0.5888 - false_positives: 437.0000 - false_negatives: 494.0000 - val_loss: 0.6589 - val_binary_accuracy: 0.6148 - val_false_positives: 152.0000 - val_false_negatives: 66.0000
# Epoch 7/10
# 142/142 [==============================] - ETA: 0s - loss: 0.6922 - binary_accuracy: 0.5945 - false_positives: 413.0000 - false_negatives: 505.0000
# Epoch 7: val_binary_accuracy did not improve from 0.61484
# 142/142 [==============================] - 23s 164ms/step - loss: 0.6922 - binary_accuracy: 0.5945 - false_positives: 413.0000 - false_negatives: 505.0000 - val_loss: 0.7704 - val_binary_accuracy: 0.5194 - val_false_positives: 272.0000 - val_false_negatives: 0.0000e+00
# Epoch 8/10
# 142/142 [==============================] - ETA: 0s - loss: 0.6802 - binary_accuracy: 0.6038 - false_positives: 404.0000 - false_negatives: 493.0000
# Epoch 8: val_binary_accuracy did not improve from 0.61484
# 142/142 [==============================] - 23s 164ms/step - loss: 0.6802 - binary_accuracy: 0.6038 - false_positives: 404.0000 - false_negatives: 493.0000 - val_loss: 0.6666 - val_binary_accuracy: 0.6131 - val_false_positives: 178.0000 - val_false_negatives: 41.0000
# Epoch 9/10
# 142/142 [==============================] - ETA: 0s - loss: 0.6873 - binary_accuracy: 0.5954 - false_positives: 408.0000 - false_negatives: 508.0000
# Epoch 9: val_binary_accuracy improved from 0.61484 to 0.63604, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint/cp-0009.ckpt
# 142/142 [==============================] - 24s 169ms/step - loss: 0.6873 - binary_accuracy: 0.5954 - false_positives: 408.0000 - false_negatives: 508.0000 - val_loss: 0.6336 - val_binary_accuracy: 0.6360 - val_false_positives: 96.0000 - val_false_negatives: 110.0000
# Epoch 10/10
# 142/142 [==============================] - ETA: 0s - loss: 0.6794 - binary_accuracy: 0.5967 - false_positives: 412.0000 - false_negatives: 501.0000
# Epoch 10: val_binary_accuracy did not improve from 0.63604
# 142/142 [==============================] - 23s 163ms/step - loss: 0.6794 - binary_accuracy: 0.5967 - false_positives: 412.0000 - false_negatives: 501.0000 - val_loss: 0.6727 - val_binary_accuracy: 0.6042 - val_false_positives: 182.0000 - val_false_negatives: 42.0000

# %% [markdown]
# # fine tuning

# %%
#load model with best performance
# model.load_weights("/home/jj/FYP/Checkpoint/EfficientNet/dense_init_checkpoint/cp-0010.ckpt")
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/dense_init_checkpoint')
model.load_weights(latest)

pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:-75]:
  layer.trainable = False
init_lr = 1e-5
steps = 10000
final_lr = 1e-6
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            ,steps
                                                            ,final_lr
                                                            ,power=0.5)
model.compile(
    optimizer= tf.keras.optimizers.RMSprop(lr_schedule),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    # ,jit_compile=True
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 100
history_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=38
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback_loss,cp_callback_acc]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.rho
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 10, 10, 1280)     53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 54,987,445
# Trainable params: 20,682,893
# Non-trainable params: 34,304,552
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6617 - binary_accuracy: 0.6219
# Epoch 1: val_loss improved from inf to 0.79519, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0001.ckpt
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.58834, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0001.ckpt
# 142/142 [==============================] - 60s 323ms/step - loss: 0.6617 - binary_accuracy: 0.6219 - val_loss: 0.7952 - val_binary_accuracy: 0.5883
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6502 - binary_accuracy: 0.6170
# Epoch 2: val_loss improved from 0.79519 to 0.65512, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0002.ckpt
#
# Epoch 2: val_binary_accuracy improved from 0.58834 to 0.63251, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0002.ckpt
# 142/142 [==============================] - 29s 205ms/step - loss: 0.6502 - binary_accuracy: 0.6170 - val_loss: 0.6551 - val_binary_accuracy: 0.6325
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6468 - binary_accuracy: 0.6268
# Epoch 3: val_loss did not improve from 0.65512
#
# Epoch 3: val_binary_accuracy did not improve from 0.63251
# 142/142 [==============================] - 28s 195ms/step - loss: 0.6468 - binary_accuracy: 0.6268 - val_loss: 0.6680 - val_binary_accuracy: 0.6219
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6275 - binary_accuracy: 0.6387
# Epoch 4: val_loss did not improve from 0.65512
#
# Epoch 4: val_binary_accuracy did not improve from 0.63251
# 142/142 [==============================] - 28s 198ms/step - loss: 0.6275 - binary_accuracy: 0.6387 - val_loss: 0.6909 - val_binary_accuracy: 0.6307
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6254 - binary_accuracy: 0.6497
# Epoch 5: val_loss improved from 0.65512 to 0.65186, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0005.ckpt
#
# Epoch 5: val_binary_accuracy improved from 0.63251 to 0.63958, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0005.ckpt
# 142/142 [==============================] - 29s 206ms/step - loss: 0.6254 - binary_accuracy: 0.6497 - val_loss: 0.6519 - val_binary_accuracy: 0.6396
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6331 - binary_accuracy: 0.6383
# Epoch 6: val_loss improved from 0.65186 to 0.63630, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0006.ckpt
#
# Epoch 6: val_binary_accuracy improved from 0.63958 to 0.65901, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0006.ckpt
# 142/142 [==============================] - 30s 209ms/step - loss: 0.6331 - binary_accuracy: 0.6383 - val_loss: 0.6363 - val_binary_accuracy: 0.6590
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6043 - binary_accuracy: 0.6709
# Epoch 7: val_loss did not improve from 0.63630
#
# Epoch 7: val_binary_accuracy improved from 0.65901 to 0.66078, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0007.ckpt
# 142/142 [==============================] - 29s 203ms/step - loss: 0.6043 - binary_accuracy: 0.6709 - val_loss: 0.6721 - val_binary_accuracy: 0.6608
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6146 - binary_accuracy: 0.6621
# Epoch 8: val_loss did not improve from 0.63630
#
# Epoch 8: val_binary_accuracy did not improve from 0.66078
# 142/142 [==============================] - 28s 196ms/step - loss: 0.6146 - binary_accuracy: 0.6621 - val_loss: 0.6650 - val_binary_accuracy: 0.6449
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6019 - binary_accuracy: 0.6674
# Epoch 9: val_loss did not improve from 0.63630
#
# Epoch 9: val_binary_accuracy improved from 0.66078 to 0.67314, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0009.ckpt
# 142/142 [==============================] - 29s 202ms/step - loss: 0.6019 - binary_accuracy: 0.6674 - val_loss: 0.6462 - val_binary_accuracy: 0.6731
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6074 - binary_accuracy: 0.6678
# Epoch 10: val_loss improved from 0.63630 to 0.63262, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0010.ckpt
#
# Epoch 10: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 28s 199ms/step - loss: 0.6074 - binary_accuracy: 0.6678 - val_loss: 0.6326 - val_binary_accuracy: 0.6731
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5893 - binary_accuracy: 0.6824
# Epoch 11: val_loss did not improve from 0.63262
#
# Epoch 11: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 28s 194ms/step - loss: 0.5893 - binary_accuracy: 0.6824 - val_loss: 0.7100 - val_binary_accuracy: 0.6572
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5866 - binary_accuracy: 0.6762
# Epoch 12: val_loss improved from 0.63262 to 0.61593, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0012.ckpt
#
# Epoch 12: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 29s 202ms/step - loss: 0.5866 - binary_accuracy: 0.6762 - val_loss: 0.6159 - val_binary_accuracy: 0.6678
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5741 - binary_accuracy: 0.6913
# Epoch 13: val_loss did not improve from 0.61593
#
# Epoch 13: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5741 - binary_accuracy: 0.6913 - val_loss: 0.6323 - val_binary_accuracy: 0.6661
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5864 - binary_accuracy: 0.7014
# Epoch 14: val_loss did not improve from 0.61593
#
# Epoch 14: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5864 - binary_accuracy: 0.7014 - val_loss: 0.6499 - val_binary_accuracy: 0.6555
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5820 - binary_accuracy: 0.6895
# Epoch 15: val_loss did not improve from 0.61593
#
# Epoch 15: val_binary_accuracy did not improve from 0.67314
# 142/142 [==============================] - 28s 199ms/step - loss: 0.5820 - binary_accuracy: 0.6895 - val_loss: 0.6190 - val_binary_accuracy: 0.6678
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5705 - binary_accuracy: 0.6917
# Epoch 16: val_loss improved from 0.61593 to 0.60227, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0016.ckpt
#
# Epoch 16: val_binary_accuracy improved from 0.67314 to 0.68728, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0016.ckpt
# 142/142 [==============================] - 30s 207ms/step - loss: 0.5705 - binary_accuracy: 0.6917 - val_loss: 0.6023 - val_binary_accuracy: 0.6873
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5564 - binary_accuracy: 0.7120
# Epoch 17: val_loss did not improve from 0.60227
#
# Epoch 17: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 199ms/step - loss: 0.5564 - binary_accuracy: 0.7120 - val_loss: 0.6518 - val_binary_accuracy: 0.6714
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5594 - binary_accuracy: 0.7054
# Epoch 18: val_loss did not improve from 0.60227
#
# Epoch 18: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 199ms/step - loss: 0.5594 - binary_accuracy: 0.7054 - val_loss: 0.6174 - val_binary_accuracy: 0.6855
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5735 - binary_accuracy: 0.6974
# Epoch 19: val_loss did not improve from 0.60227
#
# Epoch 19: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 199ms/step - loss: 0.5735 - binary_accuracy: 0.6974 - val_loss: 0.6029 - val_binary_accuracy: 0.6837
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5540 - binary_accuracy: 0.7080
# Epoch 20: val_loss did not improve from 0.60227
#
# Epoch 20: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 199ms/step - loss: 0.5540 - binary_accuracy: 0.7080 - val_loss: 0.6181 - val_binary_accuracy: 0.6731
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5604 - binary_accuracy: 0.7019
# Epoch 21: val_loss did not improve from 0.60227
#
# Epoch 21: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5604 - binary_accuracy: 0.7019 - val_loss: 0.6287 - val_binary_accuracy: 0.6784
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5518 - binary_accuracy: 0.7116
# Epoch 22: val_loss did not improve from 0.60227
#
# Epoch 22: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5518 - binary_accuracy: 0.7116 - val_loss: 0.6902 - val_binary_accuracy: 0.6608
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5464 - binary_accuracy: 0.7186
# Epoch 23: val_loss did not improve from 0.60227
#
# Epoch 23: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5464 - binary_accuracy: 0.7186 - val_loss: 0.6516 - val_binary_accuracy: 0.6731
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5528 - binary_accuracy: 0.7186
# Epoch 24: val_loss did not improve from 0.60227
#
# Epoch 24: val_binary_accuracy did not improve from 0.68728
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5528 - binary_accuracy: 0.7186 - val_loss: 0.6465 - val_binary_accuracy: 0.6784
# Epoch 25/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5363 - binary_accuracy: 0.7186
# Epoch 25: val_loss did not improve from 0.60227
#
# Epoch 25: val_binary_accuracy improved from 0.68728 to 0.69965, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0025.ckpt
# 142/142 [==============================] - 29s 203ms/step - loss: 0.5363 - binary_accuracy: 0.7186 - val_loss: 0.6077 - val_binary_accuracy: 0.6996
# Epoch 26/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5288 - binary_accuracy: 0.7253
# Epoch 26: val_loss did not improve from 0.60227
#
# Epoch 26: val_binary_accuracy did not improve from 0.69965
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5288 - binary_accuracy: 0.7253 - val_loss: 0.6251 - val_binary_accuracy: 0.6855
# Epoch 27/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5225 - binary_accuracy: 0.7261
# Epoch 27: val_loss did not improve from 0.60227
#
# Epoch 27: val_binary_accuracy did not improve from 0.69965
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5225 - binary_accuracy: 0.7261 - val_loss: 0.6683 - val_binary_accuracy: 0.6784
# Epoch 28/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5279 - binary_accuracy: 0.7275
# Epoch 28: val_loss did not improve from 0.60227
#
# Epoch 28: val_binary_accuracy did not improve from 0.69965
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5279 - binary_accuracy: 0.7275 - val_loss: 0.6777 - val_binary_accuracy: 0.6961
# Epoch 29/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5175 - binary_accuracy: 0.7319
# Epoch 29: val_loss improved from 0.60227 to 0.60213, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_loss/cp-0029.ckpt
#
# Epoch 29: val_binary_accuracy improved from 0.69965 to 0.70141, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0029.ckpt
# 142/142 [==============================] - 30s 209ms/step - loss: 0.5175 - binary_accuracy: 0.7319 - val_loss: 0.6021 - val_binary_accuracy: 0.7014
# Epoch 30/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5201 - binary_accuracy: 0.7310
# Epoch 30: val_loss did not improve from 0.60213
#
# Epoch 30: val_binary_accuracy improved from 0.70141 to 0.71201, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm_ROI_2/fine_tuning_checkpoint_acc/cp-0030.ckpt
# 142/142 [==============================] - 29s 203ms/step - loss: 0.5201 - binary_accuracy: 0.7310 - val_loss: 0.6076 - val_binary_accuracy: 0.7120
# Epoch 31/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5233 - binary_accuracy: 0.7328
# Epoch 31: val_loss did not improve from 0.60213
#
# Epoch 31: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5233 - binary_accuracy: 0.7328 - val_loss: 0.7142 - val_binary_accuracy: 0.6749
# Epoch 32/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5254 - binary_accuracy: 0.7257
# Epoch 32: val_loss did not improve from 0.60213
#
# Epoch 32: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.5254 - binary_accuracy: 0.7257 - val_loss: 0.7074 - val_binary_accuracy: 0.6749
# Epoch 33/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5093 - binary_accuracy: 0.7394
# Epoch 33: val_loss did not improve from 0.60213
#
# Epoch 33: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5093 - binary_accuracy: 0.7394 - val_loss: 0.6142 - val_binary_accuracy: 0.7032
# Epoch 34/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5048 - binary_accuracy: 0.7469
# Epoch 34: val_loss did not improve from 0.60213
#
# Epoch 34: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5048 - binary_accuracy: 0.7469 - val_loss: 0.6628 - val_binary_accuracy: 0.6890
# Epoch 35/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4980 - binary_accuracy: 0.7425
# Epoch 35: val_loss did not improve from 0.60213
#
# Epoch 35: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 195ms/step - loss: 0.4980 - binary_accuracy: 0.7425 - val_loss: 0.6442 - val_binary_accuracy: 0.7032
# Epoch 36/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5200 - binary_accuracy: 0.7297
# Epoch 36: val_loss did not improve from 0.60213
#
# Epoch 36: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.5200 - binary_accuracy: 0.7297 - val_loss: 0.6285 - val_binary_accuracy: 0.6996
# Epoch 37/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5087 - binary_accuracy: 0.7420
# Epoch 37: val_loss did not improve from 0.60213
#
# Epoch 37: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.5087 - binary_accuracy: 0.7420 - val_loss: 0.6786 - val_binary_accuracy: 0.6855
# Epoch 38/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4958 - binary_accuracy: 0.7416
# Epoch 38: val_loss did not improve from 0.60213
#
# Epoch 38: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 195ms/step - loss: 0.4958 - binary_accuracy: 0.7416 - val_loss: 0.8193 - val_binary_accuracy: 0.6749
# Epoch 39/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4880 - binary_accuracy: 0.7487
# Epoch 39: val_loss did not improve from 0.60213
#
# Epoch 39: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 195ms/step - loss: 0.4880 - binary_accuracy: 0.7487 - val_loss: 0.8293 - val_binary_accuracy: 0.6767
# Epoch 40/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5067 - binary_accuracy: 0.7429
# Epoch 40: val_loss did not improve from 0.60213
#
# Epoch 40: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.5067 - binary_accuracy: 0.7429 - val_loss: 0.7184 - val_binary_accuracy: 0.6837
# Epoch 41/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5011 - binary_accuracy: 0.7394
# Epoch 41: val_loss did not improve from 0.60213
#
# Epoch 41: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.5011 - binary_accuracy: 0.7394 - val_loss: 0.7720 - val_binary_accuracy: 0.6696
# Epoch 42/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4965 - binary_accuracy: 0.7562
# Epoch 42: val_loss did not improve from 0.60213
#
# Epoch 42: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4965 - binary_accuracy: 0.7562 - val_loss: 0.8391 - val_binary_accuracy: 0.6625
# Epoch 43/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4890 - binary_accuracy: 0.7496
# Epoch 43: val_loss did not improve from 0.60213
#
# Epoch 43: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4890 - binary_accuracy: 0.7496 - val_loss: 0.9316 - val_binary_accuracy: 0.6731
# Epoch 44/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4670 - binary_accuracy: 0.7677
# Epoch 44: val_loss did not improve from 0.60213
#
# Epoch 44: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4670 - binary_accuracy: 0.7677 - val_loss: 0.7054 - val_binary_accuracy: 0.6873
# Epoch 45/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4956 - binary_accuracy: 0.7491
# Epoch 45: val_loss did not improve from 0.60213
#
# Epoch 45: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4956 - binary_accuracy: 0.7491 - val_loss: 0.7649 - val_binary_accuracy: 0.6837
# Epoch 46/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5001 - binary_accuracy: 0.7491
# Epoch 46: val_loss did not improve from 0.60213
#
# Epoch 46: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 195ms/step - loss: 0.5001 - binary_accuracy: 0.7491 - val_loss: 0.7463 - val_binary_accuracy: 0.6961
# Epoch 47/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4706 - binary_accuracy: 0.7584
# Epoch 47: val_loss did not improve from 0.60213
#
# Epoch 47: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 195ms/step - loss: 0.4706 - binary_accuracy: 0.7584 - val_loss: 0.7530 - val_binary_accuracy: 0.6996
# Epoch 48/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4697 - binary_accuracy: 0.7619
# Epoch 48: val_loss did not improve from 0.60213
#
# Epoch 48: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4697 - binary_accuracy: 0.7619 - val_loss: 0.7658 - val_binary_accuracy: 0.6908
# Epoch 49/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4714 - binary_accuracy: 0.7610
# Epoch 49: val_loss did not improve from 0.60213
#
# Epoch 49: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4714 - binary_accuracy: 0.7610 - val_loss: 0.7686 - val_binary_accuracy: 0.7120
# Epoch 50/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4737 - binary_accuracy: 0.7668
# Epoch 50: val_loss did not improve from 0.60213
#
# Epoch 50: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4737 - binary_accuracy: 0.7668 - val_loss: 0.8428 - val_binary_accuracy: 0.6784
# Epoch 51/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4492 - binary_accuracy: 0.7694
# Epoch 51: val_loss did not improve from 0.60213
#
# Epoch 51: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4492 - binary_accuracy: 0.7694 - val_loss: 0.7625 - val_binary_accuracy: 0.7032
# Epoch 52/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4667 - binary_accuracy: 0.7624
# Epoch 52: val_loss did not improve from 0.60213
#
# Epoch 52: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4667 - binary_accuracy: 0.7624 - val_loss: 0.7019 - val_binary_accuracy: 0.6943
# Epoch 53/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4667 - binary_accuracy: 0.7646
# Epoch 53: val_loss did not improve from 0.60213
#
# Epoch 53: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4667 - binary_accuracy: 0.7646 - val_loss: 0.8134 - val_binary_accuracy: 0.6837
# Epoch 54/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4573 - binary_accuracy: 0.7739
# Epoch 54: val_loss did not improve from 0.60213
#
# Epoch 54: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 196ms/step - loss: 0.4573 - binary_accuracy: 0.7739 - val_loss: 0.9303 - val_binary_accuracy: 0.6678
# Epoch 55/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4555 - binary_accuracy: 0.7822
# Epoch 55: val_loss did not improve from 0.60213
#
# Epoch 55: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4555 - binary_accuracy: 0.7822 - val_loss: 0.7498 - val_binary_accuracy: 0.7049
# Epoch 56/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4501 - binary_accuracy: 0.7875
# Epoch 56: val_loss did not improve from 0.60213
#
# Epoch 56: val_binary_accuracy did not improve from 0.71201
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4501 - binary_accuracy: 0.7875 - val_loss: 0.8045 - val_binary_accuracy: 0.6943
# Epoch 57/100
#  25/142 [====>.........................] - ETA: 19s - loss: 0.4888 - binary_accuracy: 0.7525
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 44
#      36 cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
#      37     filepath=checkpoint_path_2,
#      38     verbose=1,
#    (...)
#      41     save_weights_only=True,
#      42     save_freq='epoch')
#      43 total_epochs = 100
# ---> 44 history_init = model.fit(train_ds_aug
#      45                     ,epochs=total_epochs
#      46                     # ,initial_epoch=38
#      47                     ,validation_data=val_ds_aug
#      48                     ,callbacks = [cp_callback_loss,cp_callback_acc]
#      49                     )
#      50 # model.save(save_dir + "inceptionv3")
#      51 plt.figure(figsize=(30,10))
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_acc_2')
model.load_weights(latest)
init_lr = 5e-6
steps = 100
final_lr = 1e-6
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            ,steps
                                                            ,final_lr
                                                            ,power=0.5)
model.compile(
    optimizer= tf.keras.optimizers.Adam(lr_schedule),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    # ,jit_compile=True
)
checkpoint_path = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss_3/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_acc_3/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 50
history_ft_2 = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=38
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback_loss,cp_callback_acc]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
# Out:
# Epoch 1/50
# 142/142 [==============================] - ETA: 0s - loss: 0.5728 - binary_accuracy: 0.6899
# Epoch 1: val_loss improved from inf to 0.55857, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss_3/cp-0001.ckpt
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.71378, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_acc_3/cp-0001.ckpt
# 142/142 [==============================] - 39s 215ms/step - loss: 0.5728 - binary_accuracy: 0.6899 - val_loss: 0.5586 - val_binary_accuracy: 0.7138
# Epoch 2/50
# 142/142 [==============================] - ETA: 0s - loss: 0.5728 - binary_accuracy: 0.7036
# Epoch 2: val_loss improved from 0.55857 to 0.55692, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss_3/cp-0002.ckpt
#
# Epoch 2: val_binary_accuracy did not improve from 0.71378
# 142/142 [==============================] - 28s 192ms/step - loss: 0.5728 - binary_accuracy: 0.7036 - val_loss: 0.5569 - val_binary_accuracy: 0.7102
# Epoch 3/50
# 142/142 [==============================] - ETA: 0s - loss: 0.5794 - binary_accuracy: 0.6966
# Epoch 3: val_loss improved from 0.55692 to 0.55635, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss_3/cp-0003.ckpt
#
# Epoch 3: val_binary_accuracy did not improve from 0.71378
# 142/142 [==============================] - 27s 192ms/step - loss: 0.5794 - binary_accuracy: 0.6966 - val_loss: 0.5564 - val_binary_accuracy: 0.7120
# Epoch 4/50
#  30/142 [=====>........................] - ETA: 17s - loss: 0.5844 - binary_accuracy: 0.6854
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 34
#      26 cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
#      27     filepath=checkpoint_path_2,
#      28     verbose=1,
#    (...)
#      31     save_weights_only=True,
#      32     save_freq='epoch')
#      33 total_epochs = 50
# ---> 34 history_ft_2 = model.fit(train_ds_aug
#      35                     ,epochs=total_epochs
#      36                     # ,initial_epoch=38
#      37                     ,validation_data=val_ds_aug
#      38                     ,callbacks = [cp_callback_loss,cp_callback_acc]
#      39                     )
#      40 # model.save(save_dir + "inceptionv3")
#      41 plt.figure(figsize=(30,10))
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_ft_2.history['loss'])
plt.subplot(132)
plt.plot(history_ft_2.history['val_loss'])
plt.subplot(133)
plt.plot(history_ft_2.history['val_binary_accuracy'])

# %%
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss')
model.load_weights(latest)
init_lr = 5e-6
steps = 1e5
final_lr = 1e-7
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            ,steps
                                                            ,final_lr
                                                            ,power=0.5)
pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:-150]:
  layer.trainable = False
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate = 5e-6),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.FalseNegatives()]
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_loss/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 100
history_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=38
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback_loss,cp_callback_acc]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 10, 10, 1280)     53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 54,987,445
# Trainable params: 27,984,821
# Non-trainable params: 27,002,624
# _________________________________________________________________
# Epoch 1/100
# 2023-02-02 07:44:44.861360: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-02 07:44:44.861406: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-02-02 07:44:44.967682: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 142/142 [==============================] - ETA: 0s - loss: 0.5828 - binary_accuracy: 0.6829 - false_positives_1: 247.0000 - false_negatives_1: 471.0000
# Epoch 1: val_loss improved from inf to 0.56650, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_loss/cp-0001.ckpt
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.72261, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0001.ckpt
# 142/142 [==============================] - 79s 494ms/step - loss: 0.5828 - binary_accuracy: 0.6829 - false_positives_1: 247.0000 - false_negatives_1: 471.0000 - val_loss: 0.5665 - val_binary_accuracy: 0.7226 - val_false_positives_1: 72.0000 - val_false_negatives_1: 85.0000
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5779 - binary_accuracy: 0.6921 - false_positives_1: 215.0000 - false_negatives_1: 482.0000
# Epoch 2: val_loss improved from 0.56650 to 0.55574, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_loss/cp-0002.ckpt
#
# Epoch 2: val_binary_accuracy improved from 0.72261 to 0.72792, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0002.ckpt
# 142/142 [==============================] - 32s 221ms/step - loss: 0.5779 - binary_accuracy: 0.6921 - false_positives_1: 215.0000 - false_negatives_1: 482.0000 - val_loss: 0.5557 - val_binary_accuracy: 0.7279 - val_false_positives_1: 50.0000 - val_false_negatives_1: 104.0000
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5852 - binary_accuracy: 0.6988 - false_positives_1: 187.0000 - false_negatives_1: 495.0000
# Epoch 3: val_loss did not improve from 0.55574
#
# Epoch 3: val_binary_accuracy improved from 0.72792 to 0.73145, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0003.ckpt
# 142/142 [==============================] - 31s 215ms/step - loss: 0.5852 - binary_accuracy: 0.6988 - false_positives_1: 187.0000 - false_negatives_1: 495.0000 - val_loss: 0.5644 - val_binary_accuracy: 0.7314 - val_false_positives_1: 71.0000 - val_false_negatives_1: 81.0000
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5848 - binary_accuracy: 0.6846 - false_positives_1: 232.0000 - false_negatives_1: 482.0000
# Epoch 4: val_loss did not improve from 0.55574
#
# Epoch 4: val_binary_accuracy did not improve from 0.73145
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5848 - binary_accuracy: 0.6846 - false_positives_1: 232.0000 - false_negatives_1: 482.0000 - val_loss: 0.5674 - val_binary_accuracy: 0.7314 - val_false_positives_1: 67.0000 - val_false_negatives_1: 85.0000
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5723 - binary_accuracy: 0.7005 - false_positives_1: 208.0000 - false_negatives_1: 470.0000
# Epoch 5: val_loss did not improve from 0.55574
#
# Epoch 5: val_binary_accuracy improved from 0.73145 to 0.73675, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0005.ckpt
# 142/142 [==============================] - 31s 216ms/step - loss: 0.5723 - binary_accuracy: 0.7005 - false_positives_1: 208.0000 - false_negatives_1: 470.0000 - val_loss: 0.5623 - val_binary_accuracy: 0.7367 - val_false_positives_1: 57.0000 - val_false_negatives_1: 92.0000
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5874 - binary_accuracy: 0.6939 - false_positives_1: 199.0000 - false_negatives_1: 494.0000
# Epoch 6: val_loss did not improve from 0.55574
#
# Epoch 6: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5874 - binary_accuracy: 0.6939 - false_positives_1: 199.0000 - false_negatives_1: 494.0000 - val_loss: 0.5576 - val_binary_accuracy: 0.7350 - val_false_positives_1: 49.0000 - val_false_negatives_1: 101.0000
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5809 - binary_accuracy: 0.6966 - false_positives_1: 216.0000 - false_negatives_1: 471.0000
# Epoch 7: val_loss did not improve from 0.55574
#
# Epoch 7: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5809 - binary_accuracy: 0.6966 - false_positives_1: 216.0000 - false_negatives_1: 471.0000 - val_loss: 0.5691 - val_binary_accuracy: 0.7261 - val_false_positives_1: 65.0000 - val_false_negatives_1: 90.0000
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5879 - binary_accuracy: 0.6935 - false_positives_1: 205.0000 - false_negatives_1: 489.0000
# Epoch 8: val_loss did not improve from 0.55574
#
# Epoch 8: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5879 - binary_accuracy: 0.6935 - false_positives_1: 205.0000 - false_negatives_1: 489.0000 - val_loss: 0.5673 - val_binary_accuracy: 0.7261 - val_false_positives_1: 71.0000 - val_false_negatives_1: 84.0000
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5769 - binary_accuracy: 0.6966 - false_positives_1: 216.0000 - false_negatives_1: 471.0000
# Epoch 9: val_loss did not improve from 0.55574
#
# Epoch 9: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5769 - binary_accuracy: 0.6966 - false_positives_1: 216.0000 - false_negatives_1: 471.0000 - val_loss: 0.5587 - val_binary_accuracy: 0.7332 - val_false_positives_1: 48.0000 - val_false_negatives_1: 103.0000
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5789 - binary_accuracy: 0.6948 - false_positives_1: 207.0000 - false_negatives_1: 484.0000
# Epoch 10: val_loss did not improve from 0.55574
#
# Epoch 10: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 213ms/step - loss: 0.5789 - binary_accuracy: 0.6948 - false_positives_1: 207.0000 - false_negatives_1: 484.0000 - val_loss: 0.5656 - val_binary_accuracy: 0.7261 - val_false_positives_1: 53.0000 - val_false_negatives_1: 102.0000
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5636 - binary_accuracy: 0.7089 - false_positives_1: 186.0000 - false_negatives_1: 473.0000
# Epoch 11: val_loss did not improve from 0.55574
#
# Epoch 11: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 213ms/step - loss: 0.5636 - binary_accuracy: 0.7089 - false_positives_1: 186.0000 - false_negatives_1: 473.0000 - val_loss: 0.5672 - val_binary_accuracy: 0.7367 - val_false_positives_1: 59.0000 - val_false_negatives_1: 90.0000
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5765 - binary_accuracy: 0.6926 - false_positives_1: 199.0000 - false_negatives_1: 497.0000
# Epoch 12: val_loss did not improve from 0.55574
#
# Epoch 12: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 214ms/step - loss: 0.5765 - binary_accuracy: 0.6926 - false_positives_1: 199.0000 - false_negatives_1: 497.0000 - val_loss: 0.5599 - val_binary_accuracy: 0.7208 - val_false_positives_1: 44.0000 - val_false_negatives_1: 114.0000
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5694 - binary_accuracy: 0.6917 - false_positives_1: 200.0000 - false_negatives_1: 498.0000
# Epoch 13: val_loss did not improve from 0.55574
#
# Epoch 13: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5694 - binary_accuracy: 0.6917 - false_positives_1: 200.0000 - false_negatives_1: 498.0000 - val_loss: 0.5598 - val_binary_accuracy: 0.7297 - val_false_positives_1: 54.0000 - val_false_negatives_1: 99.0000
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5734 - binary_accuracy: 0.6917 - false_positives_1: 207.0000 - false_negatives_1: 491.0000
# Epoch 14: val_loss did not improve from 0.55574
#
# Epoch 14: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5734 - binary_accuracy: 0.6917 - false_positives_1: 207.0000 - false_negatives_1: 491.0000 - val_loss: 0.5594 - val_binary_accuracy: 0.7350 - val_false_positives_1: 48.0000 - val_false_negatives_1: 102.0000
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5683 - binary_accuracy: 0.7027 - false_positives_1: 189.0000 - false_negatives_1: 484.0000
# Epoch 15: val_loss did not improve from 0.55574
#
# Epoch 15: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5683 - binary_accuracy: 0.7027 - false_positives_1: 189.0000 - false_negatives_1: 484.0000 - val_loss: 0.5777 - val_binary_accuracy: 0.7332 - val_false_positives_1: 76.0000 - val_false_negatives_1: 75.0000
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5693 - binary_accuracy: 0.6886 - false_positives_1: 223.0000 - false_negatives_1: 482.0000
# Epoch 16: val_loss improved from 0.55574 to 0.55160, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_loss/cp-0016.ckpt
#
# Epoch 16: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 32s 222ms/step - loss: 0.5693 - binary_accuracy: 0.6886 - false_positives_1: 223.0000 - false_negatives_1: 482.0000 - val_loss: 0.5516 - val_binary_accuracy: 0.7367 - val_false_positives_1: 47.0000 - val_false_negatives_1: 102.0000
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5626 - binary_accuracy: 0.7045 - false_positives_1: 211.0000 - false_negatives_1: 458.0000
# Epoch 17: val_loss did not improve from 0.55160
#
# Epoch 17: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5626 - binary_accuracy: 0.7045 - false_positives_1: 211.0000 - false_negatives_1: 458.0000 - val_loss: 0.5536 - val_binary_accuracy: 0.7350 - val_false_positives_1: 54.0000 - val_false_negatives_1: 96.0000
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5673 - binary_accuracy: 0.6988 - false_positives_1: 189.0000 - false_negatives_1: 493.0000
# Epoch 18: val_loss did not improve from 0.55160
#
# Epoch 18: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 212ms/step - loss: 0.5673 - binary_accuracy: 0.6988 - false_positives_1: 189.0000 - false_negatives_1: 493.0000 - val_loss: 0.5556 - val_binary_accuracy: 0.7314 - val_false_positives_1: 55.0000 - val_false_negatives_1: 97.0000
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5664 - binary_accuracy: 0.7094 - false_positives_1: 196.0000 - false_negatives_1: 462.0000
# Epoch 19: val_loss did not improve from 0.55160
#
# Epoch 19: val_binary_accuracy did not improve from 0.73675
# 142/142 [==============================] - 30s 212ms/step - loss: 0.5664 - binary_accuracy: 0.7094 - false_positives_1: 196.0000 - false_negatives_1: 462.0000 - val_loss: 0.5600 - val_binary_accuracy: 0.7367 - val_false_positives_1: 65.0000 - val_false_negatives_1: 84.0000
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5659 - binary_accuracy: 0.7027 - false_positives_1: 190.0000 - false_negatives_1: 483.0000
# Epoch 20: val_loss did not improve from 0.55160
#
# Epoch 20: val_binary_accuracy improved from 0.73675 to 0.74382, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0020.ckpt
# 142/142 [==============================] - 31s 217ms/step - loss: 0.5659 - binary_accuracy: 0.7027 - false_positives_1: 190.0000 - false_negatives_1: 483.0000 - val_loss: 0.5558 - val_binary_accuracy: 0.7438 - val_false_positives_1: 54.0000 - val_false_negatives_1: 91.0000
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5547 - binary_accuracy: 0.7138 - false_positives_1: 184.0000 - false_negatives_1: 464.0000
# Epoch 21: val_loss did not improve from 0.55160
#
# Epoch 21: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5547 - binary_accuracy: 0.7138 - false_positives_1: 184.0000 - false_negatives_1: 464.0000 - val_loss: 0.5619 - val_binary_accuracy: 0.7173 - val_false_positives_1: 72.0000 - val_false_negatives_1: 88.0000
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5526 - binary_accuracy: 0.7129 - false_positives_1: 198.0000 - false_negatives_1: 452.0000
# Epoch 22: val_loss did not improve from 0.55160
#
# Epoch 22: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5526 - binary_accuracy: 0.7129 - false_positives_1: 198.0000 - false_negatives_1: 452.0000 - val_loss: 0.5580 - val_binary_accuracy: 0.7191 - val_false_positives_1: 66.0000 - val_false_negatives_1: 93.0000
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5554 - binary_accuracy: 0.7142 - false_positives_1: 191.0000 - false_negatives_1: 456.0000
# Epoch 23: val_loss did not improve from 0.55160
#
# Epoch 23: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5554 - binary_accuracy: 0.7142 - false_positives_1: 191.0000 - false_negatives_1: 456.0000 - val_loss: 0.5539 - val_binary_accuracy: 0.7438 - val_false_positives_1: 50.0000 - val_false_negatives_1: 95.0000
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5566 - binary_accuracy: 0.7080 - false_positives_1: 187.0000 - false_negatives_1: 474.0000
# Epoch 24: val_loss did not improve from 0.55160
#
# Epoch 24: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5566 - binary_accuracy: 0.7080 - false_positives_1: 187.0000 - false_negatives_1: 474.0000 - val_loss: 0.5762 - val_binary_accuracy: 0.7279 - val_false_positives_1: 78.0000 - val_false_negatives_1: 76.0000
# Epoch 25/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5531 - binary_accuracy: 0.7160 - false_positives_1: 183.0000 - false_negatives_1: 460.0000
# Epoch 25: val_loss did not improve from 0.55160
#
# Epoch 25: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5531 - binary_accuracy: 0.7160 - false_positives_1: 183.0000 - false_negatives_1: 460.0000 - val_loss: 0.5769 - val_binary_accuracy: 0.7226 - val_false_positives_1: 76.0000 - val_false_negatives_1: 81.0000
# Epoch 26/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5626 - binary_accuracy: 0.7067 - false_positives_1: 214.0000 - false_negatives_1: 450.0000
# Epoch 26: val_loss did not improve from 0.55160
#
# Epoch 26: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5626 - binary_accuracy: 0.7067 - false_positives_1: 214.0000 - false_negatives_1: 450.0000 - val_loss: 0.5629 - val_binary_accuracy: 0.7279 - val_false_positives_1: 61.0000 - val_false_negatives_1: 93.0000
# Epoch 27/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5500 - binary_accuracy: 0.7102 - false_positives_1: 218.0000 - false_negatives_1: 438.0000
# Epoch 27: val_loss did not improve from 0.55160
#
# Epoch 27: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5500 - binary_accuracy: 0.7102 - false_positives_1: 218.0000 - false_negatives_1: 438.0000 - val_loss: 0.5861 - val_binary_accuracy: 0.7297 - val_false_positives_1: 83.0000 - val_false_negatives_1: 70.0000
# Epoch 28/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5578 - binary_accuracy: 0.7054 - false_positives_1: 196.0000 - false_negatives_1: 471.0000
# Epoch 28: val_loss did not improve from 0.55160
#
# Epoch 28: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5578 - binary_accuracy: 0.7054 - false_positives_1: 196.0000 - false_negatives_1: 471.0000 - val_loss: 0.5632 - val_binary_accuracy: 0.7297 - val_false_positives_1: 60.0000 - val_false_negatives_1: 93.0000
# Epoch 29/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5558 - binary_accuracy: 0.7054 - false_positives_1: 184.0000 - false_negatives_1: 483.0000
# Epoch 29: val_loss did not improve from 0.55160
#
# Epoch 29: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5558 - binary_accuracy: 0.7054 - false_positives_1: 184.0000 - false_negatives_1: 483.0000 - val_loss: 0.5551 - val_binary_accuracy: 0.7350 - val_false_positives_1: 38.0000 - val_false_negatives_1: 112.0000
# Epoch 30/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5524 - binary_accuracy: 0.7023 - false_positives_1: 211.0000 - false_negatives_1: 463.0000
# Epoch 30: val_loss did not improve from 0.55160
#
# Epoch 30: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 210ms/step - loss: 0.5524 - binary_accuracy: 0.7023 - false_positives_1: 211.0000 - false_negatives_1: 463.0000 - val_loss: 0.5702 - val_binary_accuracy: 0.7155 - val_false_positives_1: 85.0000 - val_false_negatives_1: 76.0000
# Epoch 31/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5449 - binary_accuracy: 0.7186 - false_positives_1: 179.0000 - false_negatives_1: 458.0000
# Epoch 31: val_loss did not improve from 0.55160
#
# Epoch 31: val_binary_accuracy did not improve from 0.74382
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5449 - binary_accuracy: 0.7186 - false_positives_1: 179.0000 - false_negatives_1: 458.0000 - val_loss: 0.5638 - val_binary_accuracy: 0.7350 - val_false_positives_1: 59.0000 - val_false_negatives_1: 91.0000
# Epoch 32/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5483 - binary_accuracy: 0.7231 - false_positives_1: 204.0000 - false_negatives_1: 423.0000
# Epoch 32: val_loss did not improve from 0.55160
#
# Epoch 32: val_binary_accuracy improved from 0.74382 to 0.74558, saving model to /home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-0032.ckpt
# 142/142 [==============================] - 34s 235ms/step - loss: 0.5483 - binary_accuracy: 0.7231 - false_positives_1: 204.0000 - false_negatives_1: 423.0000 - val_loss: 0.5655 - val_binary_accuracy: 0.7456 - val_false_positives_1: 50.0000 - val_false_negatives_1: 94.0000
# Epoch 33/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5563 - binary_accuracy: 0.7129 - false_positives_1: 190.0000 - false_negatives_1: 460.0000
# Epoch 33: val_loss did not improve from 0.55160
#
# Epoch 33: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5563 - binary_accuracy: 0.7129 - false_positives_1: 190.0000 - false_negatives_1: 460.0000 - val_loss: 0.5651 - val_binary_accuracy: 0.7367 - val_false_positives_1: 68.0000 - val_false_negatives_1: 81.0000
# Epoch 34/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5341 - binary_accuracy: 0.7297 - false_positives_1: 197.0000 - false_negatives_1: 415.0000
# Epoch 34: val_loss did not improve from 0.55160
#
# Epoch 34: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 30s 211ms/step - loss: 0.5341 - binary_accuracy: 0.7297 - false_positives_1: 197.0000 - false_negatives_1: 415.0000 - val_loss: 0.5823 - val_binary_accuracy: 0.7297 - val_false_positives_1: 72.0000 - val_false_negatives_1: 81.0000
# Epoch 35/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5493 - binary_accuracy: 0.7204 - false_positives_1: 208.0000 - false_negatives_1: 425.0000
# Epoch 35: val_loss did not improve from 0.55160
#
# Epoch 35: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5493 - binary_accuracy: 0.7204 - false_positives_1: 208.0000 - false_negatives_1: 425.0000 - val_loss: 0.6008 - val_binary_accuracy: 0.7208 - val_false_positives_1: 88.0000 - val_false_negatives_1: 70.0000
# Epoch 36/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5429 - binary_accuracy: 0.7200 - false_positives_1: 178.0000 - false_negatives_1: 456.0000
# Epoch 36: val_loss did not improve from 0.55160
#
# Epoch 36: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5429 - binary_accuracy: 0.7200 - false_positives_1: 178.0000 - false_negatives_1: 456.0000 - val_loss: 0.5964 - val_binary_accuracy: 0.7244 - val_false_positives_1: 71.0000 - val_false_negatives_1: 85.0000
# Epoch 37/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5379 - binary_accuracy: 0.7403 - false_positives_1: 168.0000 - false_negatives_1: 420.0000
# Epoch 37: val_loss did not improve from 0.55160
#
# Epoch 37: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5379 - binary_accuracy: 0.7403 - false_positives_1: 168.0000 - false_negatives_1: 420.0000 - val_loss: 0.5765 - val_binary_accuracy: 0.7297 - val_false_positives_1: 72.0000 - val_false_negatives_1: 81.0000
# Epoch 38/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5440 - binary_accuracy: 0.7244 - false_positives_1: 189.0000 - false_negatives_1: 435.0000
# Epoch 38: val_loss did not improve from 0.55160
#
# Epoch 38: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5440 - binary_accuracy: 0.7244 - false_positives_1: 189.0000 - false_negatives_1: 435.0000 - val_loss: 0.5792 - val_binary_accuracy: 0.7244 - val_false_positives_1: 65.0000 - val_false_negatives_1: 91.0000
# Epoch 39/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5243 - binary_accuracy: 0.7284 - false_positives_1: 177.0000 - false_negatives_1: 438.0000
# Epoch 39: val_loss did not improve from 0.55160
#
# Epoch 39: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5243 - binary_accuracy: 0.7284 - false_positives_1: 177.0000 - false_negatives_1: 438.0000 - val_loss: 0.6176 - val_binary_accuracy: 0.7332 - val_false_positives_1: 75.0000 - val_false_negatives_1: 76.0000
# Epoch 40/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5470 - binary_accuracy: 0.7208 - false_positives_1: 165.0000 - false_negatives_1: 467.0000
# Epoch 40: val_loss did not improve from 0.55160
#
# Epoch 40: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5470 - binary_accuracy: 0.7208 - false_positives_1: 165.0000 - false_negatives_1: 467.0000 - val_loss: 0.6198 - val_binary_accuracy: 0.7120 - val_false_positives_1: 92.0000 - val_false_negatives_1: 71.0000
# Epoch 41/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5382 - binary_accuracy: 0.7186 - false_positives_1: 183.0000 - false_negatives_1: 454.0000
# Epoch 41: val_loss did not improve from 0.55160
#
# Epoch 41: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5382 - binary_accuracy: 0.7186 - false_positives_1: 183.0000 - false_negatives_1: 454.0000 - val_loss: 0.5806 - val_binary_accuracy: 0.7279 - val_false_positives_1: 67.0000 - val_false_negatives_1: 87.0000
# Epoch 42/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5398 - binary_accuracy: 0.7253 - false_positives_1: 205.0000 - false_negatives_1: 417.0000
# Epoch 42: val_loss did not improve from 0.55160
#
# Epoch 42: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5398 - binary_accuracy: 0.7253 - false_positives_1: 205.0000 - false_negatives_1: 417.0000 - val_loss: 0.5935 - val_binary_accuracy: 0.7102 - val_false_positives_1: 89.0000 - val_false_negatives_1: 75.0000
# Epoch 43/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5399 - binary_accuracy: 0.7253 - false_positives_1: 191.0000 - false_negatives_1: 431.0000
# Epoch 43: val_loss did not improve from 0.55160
#
# Epoch 43: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5399 - binary_accuracy: 0.7253 - false_positives_1: 191.0000 - false_negatives_1: 431.0000 - val_loss: 0.5569 - val_binary_accuracy: 0.7226 - val_false_positives_1: 38.0000 - val_false_negatives_1: 119.0000
# Epoch 44/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5293 - binary_accuracy: 0.7226 - false_positives_1: 192.0000 - false_negatives_1: 436.0000
# Epoch 44: val_loss did not improve from 0.55160
#
# Epoch 44: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 206ms/step - loss: 0.5293 - binary_accuracy: 0.7226 - false_positives_1: 192.0000 - false_negatives_1: 436.0000 - val_loss: 0.5780 - val_binary_accuracy: 0.7244 - val_false_positives_1: 65.0000 - val_false_negatives_1: 91.0000
# Epoch 45/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5341 - binary_accuracy: 0.7266 - false_positives_1: 173.0000 - false_negatives_1: 446.0000
# Epoch 45: val_loss did not improve from 0.55160
#
# Epoch 45: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 206ms/step - loss: 0.5341 - binary_accuracy: 0.7266 - false_positives_1: 173.0000 - false_negatives_1: 446.0000 - val_loss: 0.5861 - val_binary_accuracy: 0.7120 - val_false_positives_1: 76.0000 - val_false_negatives_1: 87.0000
# Epoch 46/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5319 - binary_accuracy: 0.7363 - false_positives_1: 168.0000 - false_negatives_1: 429.0000
# Epoch 46: val_loss did not improve from 0.55160
#
# Epoch 46: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5319 - binary_accuracy: 0.7363 - false_positives_1: 168.0000 - false_negatives_1: 429.0000 - val_loss: 0.5650 - val_binary_accuracy: 0.7279 - val_false_positives_1: 57.0000 - val_false_negatives_1: 97.0000
# Epoch 47/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5240 - binary_accuracy: 0.7306 - false_positives_1: 193.0000 - false_negatives_1: 417.0000
# Epoch 47: val_loss did not improve from 0.55160
#
# Epoch 47: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5240 - binary_accuracy: 0.7306 - false_positives_1: 193.0000 - false_negatives_1: 417.0000 - val_loss: 0.6171 - val_binary_accuracy: 0.7120 - val_false_positives_1: 92.0000 - val_false_negatives_1: 71.0000
# Epoch 48/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5244 - binary_accuracy: 0.7429 - false_positives_1: 178.0000 - false_negatives_1: 404.0000
# Epoch 48: val_loss did not improve from 0.55160
#
# Epoch 48: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5244 - binary_accuracy: 0.7429 - false_positives_1: 178.0000 - false_negatives_1: 404.0000 - val_loss: 0.6473 - val_binary_accuracy: 0.6979 - val_false_positives_1: 103.0000 - val_false_negatives_1: 68.0000
# Epoch 49/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5268 - binary_accuracy: 0.7332 - false_positives_1: 194.0000 - false_negatives_1: 410.0000
# Epoch 49: val_loss did not improve from 0.55160
#
# Epoch 49: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5268 - binary_accuracy: 0.7332 - false_positives_1: 194.0000 - false_negatives_1: 410.0000 - val_loss: 0.6092 - val_binary_accuracy: 0.7032 - val_false_positives_1: 88.0000 - val_false_negatives_1: 80.0000
# Epoch 50/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5154 - binary_accuracy: 0.7372 - false_positives_1: 172.0000 - false_negatives_1: 423.0000
# Epoch 50: val_loss did not improve from 0.55160
#
# Epoch 50: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5154 - binary_accuracy: 0.7372 - false_positives_1: 172.0000 - false_negatives_1: 423.0000 - val_loss: 0.6494 - val_binary_accuracy: 0.6979 - val_false_positives_1: 104.0000 - val_false_negatives_1: 67.0000
# Epoch 51/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5094 - binary_accuracy: 0.7482 - false_positives_1: 177.0000 - false_negatives_1: 393.0000
# Epoch 51: val_loss did not improve from 0.55160
#
# Epoch 51: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5094 - binary_accuracy: 0.7482 - false_positives_1: 177.0000 - false_negatives_1: 393.0000 - val_loss: 0.6214 - val_binary_accuracy: 0.7102 - val_false_positives_1: 96.0000 - val_false_negatives_1: 68.0000
# Epoch 52/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5220 - binary_accuracy: 0.7372 - false_positives_1: 190.0000 - false_negatives_1: 405.0000
# Epoch 52: val_loss did not improve from 0.55160
#
# Epoch 52: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5220 - binary_accuracy: 0.7372 - false_positives_1: 190.0000 - false_negatives_1: 405.0000 - val_loss: 0.6079 - val_binary_accuracy: 0.7085 - val_false_positives_1: 81.0000 - val_false_negatives_1: 84.0000
# Epoch 53/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5197 - binary_accuracy: 0.7323 - false_positives_1: 186.0000 - false_negatives_1: 420.0000
# Epoch 53: val_loss did not improve from 0.55160
#
# Epoch 53: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5197 - binary_accuracy: 0.7323 - false_positives_1: 186.0000 - false_negatives_1: 420.0000 - val_loss: 0.6634 - val_binary_accuracy: 0.6873 - val_false_positives_1: 113.0000 - val_false_negatives_1: 64.0000
# Epoch 54/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5236 - binary_accuracy: 0.7376 - false_positives_1: 188.0000 - false_negatives_1: 406.0000
# Epoch 54: val_loss did not improve from 0.55160
#
# Epoch 54: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5236 - binary_accuracy: 0.7376 - false_positives_1: 188.0000 - false_negatives_1: 406.0000 - val_loss: 0.5942 - val_binary_accuracy: 0.7208 - val_false_positives_1: 74.0000 - val_false_negatives_1: 84.0000
# Epoch 55/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5148 - binary_accuracy: 0.7412 - false_positives_1: 175.0000 - false_negatives_1: 411.0000
# Epoch 55: val_loss did not improve from 0.55160
#
# Epoch 55: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5148 - binary_accuracy: 0.7412 - false_positives_1: 175.0000 - false_negatives_1: 411.0000 - val_loss: 0.6308 - val_binary_accuracy: 0.7226 - val_false_positives_1: 83.0000 - val_false_negatives_1: 74.0000
# Epoch 56/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5255 - binary_accuracy: 0.7288 - false_positives_1: 188.0000 - false_negatives_1: 426.0000
# Epoch 56: val_loss did not improve from 0.55160
#
# Epoch 56: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5255 - binary_accuracy: 0.7288 - false_positives_1: 188.0000 - false_negatives_1: 426.0000 - val_loss: 0.6131 - val_binary_accuracy: 0.7314 - val_false_positives_1: 62.0000 - val_false_negatives_1: 90.0000
# Epoch 57/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5096 - binary_accuracy: 0.7473 - false_positives_1: 178.0000 - false_negatives_1: 394.0000
# Epoch 57: val_loss did not improve from 0.55160
#
# Epoch 57: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5096 - binary_accuracy: 0.7473 - false_positives_1: 178.0000 - false_negatives_1: 394.0000 - val_loss: 0.5929 - val_binary_accuracy: 0.7261 - val_false_positives_1: 64.0000 - val_false_negatives_1: 91.0000
# Epoch 58/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5118 - binary_accuracy: 0.7429 - false_positives_1: 163.0000 - false_negatives_1: 419.0000
# Epoch 58: val_loss did not improve from 0.55160
#
# Epoch 58: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5118 - binary_accuracy: 0.7429 - false_positives_1: 163.0000 - false_negatives_1: 419.0000 - val_loss: 0.6613 - val_binary_accuracy: 0.7014 - val_false_positives_1: 99.0000 - val_false_negatives_1: 70.0000
# Epoch 59/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5269 - binary_accuracy: 0.7235 - false_positives_1: 193.0000 - false_negatives_1: 433.0000
# Epoch 59: val_loss did not improve from 0.55160
#
# Epoch 59: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5269 - binary_accuracy: 0.7235 - false_positives_1: 193.0000 - false_negatives_1: 433.0000 - val_loss: 0.5883 - val_binary_accuracy: 0.7191 - val_false_positives_1: 75.0000 - val_false_negatives_1: 84.0000
# Epoch 60/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5084 - binary_accuracy: 0.7359 - false_positives_1: 172.0000 - false_negatives_1: 426.0000
# Epoch 60: val_loss did not improve from 0.55160
#
# Epoch 60: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5084 - binary_accuracy: 0.7359 - false_positives_1: 172.0000 - false_negatives_1: 426.0000 - val_loss: 0.6344 - val_binary_accuracy: 0.7350 - val_false_positives_1: 76.0000 - val_false_negatives_1: 74.0000
# Epoch 61/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5088 - binary_accuracy: 0.7438 - false_positives_1: 193.0000 - false_negatives_1: 387.0000
# Epoch 61: val_loss did not improve from 0.55160
#
# Epoch 61: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5088 - binary_accuracy: 0.7438 - false_positives_1: 193.0000 - false_negatives_1: 387.0000 - val_loss: 0.6112 - val_binary_accuracy: 0.7208 - val_false_positives_1: 71.0000 - val_false_negatives_1: 87.0000
# Epoch 62/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5002 - binary_accuracy: 0.7527 - false_positives_1: 160.0000 - false_negatives_1: 400.0000
# Epoch 62: val_loss did not improve from 0.55160
#
# Epoch 62: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5002 - binary_accuracy: 0.7527 - false_positives_1: 160.0000 - false_negatives_1: 400.0000 - val_loss: 0.6272 - val_binary_accuracy: 0.7279 - val_false_positives_1: 64.0000 - val_false_negatives_1: 90.0000
# Epoch 63/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5037 - binary_accuracy: 0.7527 - false_positives_1: 172.0000 - false_negatives_1: 388.0000
# Epoch 63: val_loss did not improve from 0.55160
#
# Epoch 63: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5037 - binary_accuracy: 0.7527 - false_positives_1: 172.0000 - false_negatives_1: 388.0000 - val_loss: 0.5976 - val_binary_accuracy: 0.7350 - val_false_positives_1: 60.0000 - val_false_negatives_1: 90.0000
# Epoch 64/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4991 - binary_accuracy: 0.7571 - false_positives_1: 168.0000 - false_negatives_1: 382.0000
# Epoch 64: val_loss did not improve from 0.55160
#
# Epoch 64: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4991 - binary_accuracy: 0.7571 - false_positives_1: 168.0000 - false_negatives_1: 382.0000 - val_loss: 0.6117 - val_binary_accuracy: 0.7261 - val_false_positives_1: 63.0000 - val_false_negatives_1: 92.0000
# Epoch 65/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5054 - binary_accuracy: 0.7549 - false_positives_1: 172.0000 - false_negatives_1: 383.0000
# Epoch 65: val_loss did not improve from 0.55160
#
# Epoch 65: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5054 - binary_accuracy: 0.7549 - false_positives_1: 172.0000 - false_negatives_1: 383.0000 - val_loss: 0.6467 - val_binary_accuracy: 0.7261 - val_false_positives_1: 71.0000 - val_false_negatives_1: 84.0000
# Epoch 66/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5024 - binary_accuracy: 0.7482 - false_positives_1: 170.0000 - false_negatives_1: 400.0000
# Epoch 66: val_loss did not improve from 0.55160
#
# Epoch 66: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5024 - binary_accuracy: 0.7482 - false_positives_1: 170.0000 - false_negatives_1: 400.0000 - val_loss: 0.7152 - val_binary_accuracy: 0.7085 - val_false_positives_1: 91.0000 - val_false_negatives_1: 74.0000
# Epoch 67/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4967 - binary_accuracy: 0.7487 - false_positives_1: 181.0000 - false_negatives_1: 388.0000
# Epoch 67: val_loss did not improve from 0.55160
#
# Epoch 67: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4967 - binary_accuracy: 0.7487 - false_positives_1: 181.0000 - false_negatives_1: 388.0000 - val_loss: 0.7262 - val_binary_accuracy: 0.7173 - val_false_positives_1: 88.0000 - val_false_negatives_1: 72.0000
# Epoch 68/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5012 - binary_accuracy: 0.7513 - false_positives_1: 171.0000 - false_negatives_1: 392.0000
# Epoch 68: val_loss did not improve from 0.55160
#
# Epoch 68: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5012 - binary_accuracy: 0.7513 - false_positives_1: 171.0000 - false_negatives_1: 392.0000 - val_loss: 0.7268 - val_binary_accuracy: 0.7032 - val_false_positives_1: 97.0000 - val_false_negatives_1: 71.0000
# Epoch 69/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4973 - binary_accuracy: 0.7478 - false_positives_1: 158.0000 - false_negatives_1: 413.0000
# Epoch 69: val_loss did not improve from 0.55160
#
# Epoch 69: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4973 - binary_accuracy: 0.7478 - false_positives_1: 158.0000 - false_negatives_1: 413.0000 - val_loss: 0.6598 - val_binary_accuracy: 0.7191 - val_false_positives_1: 79.0000 - val_false_negatives_1: 80.0000
# Epoch 70/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5123 - binary_accuracy: 0.7429 - false_positives_1: 187.0000 - false_negatives_1: 395.0000
# Epoch 70: val_loss did not improve from 0.55160
#
# Epoch 70: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 30s 212ms/step - loss: 0.5123 - binary_accuracy: 0.7429 - false_positives_1: 187.0000 - false_negatives_1: 395.0000 - val_loss: 0.6250 - val_binary_accuracy: 0.7208 - val_false_positives_1: 75.0000 - val_false_negatives_1: 83.0000
# Epoch 71/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5094 - binary_accuracy: 0.7412 - false_positives_1: 197.0000 - false_negatives_1: 389.0000
# Epoch 71: val_loss did not improve from 0.55160
#
# Epoch 71: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5094 - binary_accuracy: 0.7412 - false_positives_1: 197.0000 - false_negatives_1: 389.0000 - val_loss: 0.6516 - val_binary_accuracy: 0.7155 - val_false_positives_1: 75.0000 - val_false_negatives_1: 86.0000
# Epoch 72/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4917 - binary_accuracy: 0.7403 - false_positives_1: 187.0000 - false_negatives_1: 401.0000
# Epoch 72: val_loss did not improve from 0.55160
#
# Epoch 72: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4917 - binary_accuracy: 0.7403 - false_positives_1: 187.0000 - false_negatives_1: 401.0000 - val_loss: 0.6982 - val_binary_accuracy: 0.7244 - val_false_positives_1: 78.0000 - val_false_negatives_1: 78.0000
# Epoch 73/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5029 - binary_accuracy: 0.7540 - false_positives_1: 172.0000 - false_negatives_1: 385.0000
# Epoch 73: val_loss did not improve from 0.55160
#
# Epoch 73: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.5029 - binary_accuracy: 0.7540 - false_positives_1: 172.0000 - false_negatives_1: 385.0000 - val_loss: 0.6433 - val_binary_accuracy: 0.7226 - val_false_positives_1: 67.0000 - val_false_negatives_1: 90.0000
# Epoch 74/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4969 - binary_accuracy: 0.7500 - false_positives_1: 158.0000 - false_negatives_1: 408.0000
# Epoch 74: val_loss did not improve from 0.55160
#
# Epoch 74: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4969 - binary_accuracy: 0.7500 - false_positives_1: 158.0000 - false_negatives_1: 408.0000 - val_loss: 0.7270 - val_binary_accuracy: 0.6961 - val_false_positives_1: 94.0000 - val_false_negatives_1: 78.0000
# Epoch 75/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4879 - binary_accuracy: 0.7522 - false_positives_1: 176.0000 - false_negatives_1: 385.0000
# Epoch 75: val_loss did not improve from 0.55160
#
# Epoch 75: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4879 - binary_accuracy: 0.7522 - false_positives_1: 176.0000 - false_negatives_1: 385.0000 - val_loss: 0.7012 - val_binary_accuracy: 0.7085 - val_false_positives_1: 85.0000 - val_false_negatives_1: 80.0000
# Epoch 76/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4892 - binary_accuracy: 0.7544 - false_positives_1: 175.0000 - false_negatives_1: 381.0000
# Epoch 76: val_loss did not improve from 0.55160
#
# Epoch 76: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4892 - binary_accuracy: 0.7544 - false_positives_1: 175.0000 - false_negatives_1: 381.0000 - val_loss: 0.6881 - val_binary_accuracy: 0.7138 - val_false_positives_1: 78.0000 - val_false_negatives_1: 84.0000
# Epoch 77/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5028 - binary_accuracy: 0.7447 - false_positives_1: 178.0000 - false_negatives_1: 400.0000
# Epoch 77: val_loss did not improve from 0.55160
#
# Epoch 77: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5028 - binary_accuracy: 0.7447 - false_positives_1: 178.0000 - false_negatives_1: 400.0000 - val_loss: 0.6899 - val_binary_accuracy: 0.7120 - val_false_positives_1: 75.0000 - val_false_negatives_1: 88.0000
# Epoch 78/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5040 - binary_accuracy: 0.7491 - false_positives_1: 159.0000 - false_negatives_1: 409.0000
# Epoch 78: val_loss did not improve from 0.55160
#
# Epoch 78: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.5040 - binary_accuracy: 0.7491 - false_positives_1: 159.0000 - false_negatives_1: 409.0000 - val_loss: 0.6761 - val_binary_accuracy: 0.7049 - val_false_positives_1: 80.0000 - val_false_negatives_1: 87.0000
# Epoch 79/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4938 - binary_accuracy: 0.7522 - false_positives_1: 176.0000 - false_negatives_1: 385.0000
# Epoch 79: val_loss did not improve from 0.55160
#
# Epoch 79: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4938 - binary_accuracy: 0.7522 - false_positives_1: 176.0000 - false_negatives_1: 385.0000 - val_loss: 0.6792 - val_binary_accuracy: 0.7049 - val_false_positives_1: 76.0000 - val_false_negatives_1: 91.0000
# Epoch 80/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4795 - binary_accuracy: 0.7557 - false_positives_1: 183.0000 - false_negatives_1: 370.0000
# Epoch 80: val_loss did not improve from 0.55160
#
# Epoch 80: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4795 - binary_accuracy: 0.7557 - false_positives_1: 183.0000 - false_negatives_1: 370.0000 - val_loss: 0.6852 - val_binary_accuracy: 0.6890 - val_false_positives_1: 93.0000 - val_false_negatives_1: 83.0000
# Epoch 81/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4950 - binary_accuracy: 0.7531 - false_positives_1: 197.0000 - false_negatives_1: 362.0000
# Epoch 81: val_loss did not improve from 0.55160
#
# Epoch 81: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4950 - binary_accuracy: 0.7531 - false_positives_1: 197.0000 - false_negatives_1: 362.0000 - val_loss: 0.6610 - val_binary_accuracy: 0.6873 - val_false_positives_1: 102.0000 - val_false_negatives_1: 75.0000
# Epoch 82/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4803 - binary_accuracy: 0.7571 - false_positives_1: 175.0000 - false_negatives_1: 375.0000
# Epoch 82: val_loss did not improve from 0.55160
#
# Epoch 82: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4803 - binary_accuracy: 0.7571 - false_positives_1: 175.0000 - false_negatives_1: 375.0000 - val_loss: 0.6513 - val_binary_accuracy: 0.7138 - val_false_positives_1: 75.0000 - val_false_negatives_1: 87.0000
# Epoch 83/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4796 - binary_accuracy: 0.7677 - false_positives_1: 179.0000 - false_negatives_1: 347.0000
# Epoch 83: val_loss did not improve from 0.55160
#
# Epoch 83: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4796 - binary_accuracy: 0.7677 - false_positives_1: 179.0000 - false_negatives_1: 347.0000 - val_loss: 0.6953 - val_binary_accuracy: 0.6873 - val_false_positives_1: 96.0000 - val_false_negatives_1: 81.0000
# Epoch 84/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4744 - binary_accuracy: 0.7694 - false_positives_1: 166.0000 - false_negatives_1: 356.0000
# Epoch 84: val_loss did not improve from 0.55160
#
# Epoch 84: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4744 - binary_accuracy: 0.7694 - false_positives_1: 166.0000 - false_negatives_1: 356.0000 - val_loss: 0.7315 - val_binary_accuracy: 0.6678 - val_false_positives_1: 116.0000 - val_false_negatives_1: 72.0000
# Epoch 85/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4931 - binary_accuracy: 0.7575 - false_positives_1: 164.0000 - false_negatives_1: 385.0000
# Epoch 85: val_loss did not improve from 0.55160
#
# Epoch 85: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4931 - binary_accuracy: 0.7575 - false_positives_1: 164.0000 - false_negatives_1: 385.0000 - val_loss: 0.6404 - val_binary_accuracy: 0.7155 - val_false_positives_1: 73.0000 - val_false_negatives_1: 88.0000
# Epoch 86/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4729 - binary_accuracy: 0.7637 - false_positives_1: 184.0000 - false_negatives_1: 351.0000
# Epoch 86: val_loss did not improve from 0.55160
#
# Epoch 86: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4729 - binary_accuracy: 0.7637 - false_positives_1: 184.0000 - false_negatives_1: 351.0000 - val_loss: 0.6238 - val_binary_accuracy: 0.7279 - val_false_positives_1: 44.0000 - val_false_negatives_1: 110.0000
# Epoch 87/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4697 - binary_accuracy: 0.7712 - false_positives_1: 160.0000 - false_negatives_1: 358.0000
# Epoch 87: val_loss did not improve from 0.55160
#
# Epoch 87: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4697 - binary_accuracy: 0.7712 - false_positives_1: 160.0000 - false_negatives_1: 358.0000 - val_loss: 0.6637 - val_binary_accuracy: 0.7049 - val_false_positives_1: 81.0000 - val_false_negatives_1: 86.0000
# Epoch 88/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4784 - binary_accuracy: 0.7690 - false_positives_1: 154.0000 - false_negatives_1: 369.0000
# Epoch 88: val_loss did not improve from 0.55160
#
# Epoch 88: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4784 - binary_accuracy: 0.7690 - false_positives_1: 154.0000 - false_negatives_1: 369.0000 - val_loss: 0.6389 - val_binary_accuracy: 0.7261 - val_false_positives_1: 55.0000 - val_false_negatives_1: 100.0000
# Epoch 89/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4873 - binary_accuracy: 0.7637 - false_positives_1: 174.0000 - false_negatives_1: 361.0000
# Epoch 89: val_loss did not improve from 0.55160
#
# Epoch 89: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4873 - binary_accuracy: 0.7637 - false_positives_1: 174.0000 - false_negatives_1: 361.0000 - val_loss: 0.6192 - val_binary_accuracy: 0.7208 - val_false_positives_1: 48.0000 - val_false_negatives_1: 110.0000
# Epoch 90/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4835 - binary_accuracy: 0.7615 - false_positives_1: 166.0000 - false_negatives_1: 374.0000
# Epoch 90: val_loss did not improve from 0.55160
#
# Epoch 90: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4835 - binary_accuracy: 0.7615 - false_positives_1: 166.0000 - false_negatives_1: 374.0000 - val_loss: 0.7061 - val_binary_accuracy: 0.6890 - val_false_positives_1: 95.0000 - val_false_negatives_1: 81.0000
# Epoch 91/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4731 - binary_accuracy: 0.7619 - false_positives_1: 169.0000 - false_negatives_1: 370.0000
# Epoch 91: val_loss did not improve from 0.55160
#
# Epoch 91: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4731 - binary_accuracy: 0.7619 - false_positives_1: 169.0000 - false_negatives_1: 370.0000 - val_loss: 0.6501 - val_binary_accuracy: 0.7067 - val_false_positives_1: 73.0000 - val_false_negatives_1: 93.0000
# Epoch 92/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4799 - binary_accuracy: 0.7641 - false_positives_1: 166.0000 - false_negatives_1: 368.0000
# Epoch 92: val_loss did not improve from 0.55160
#
# Epoch 92: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4799 - binary_accuracy: 0.7641 - false_positives_1: 166.0000 - false_negatives_1: 368.0000 - val_loss: 0.6201 - val_binary_accuracy: 0.7085 - val_false_positives_1: 60.0000 - val_false_negatives_1: 105.0000
# Epoch 93/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4646 - binary_accuracy: 0.7619 - false_positives_1: 187.0000 - false_negatives_1: 352.0000
# Epoch 93: val_loss did not improve from 0.55160
#
# Epoch 93: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4646 - binary_accuracy: 0.7619 - false_positives_1: 187.0000 - false_negatives_1: 352.0000 - val_loss: 0.6631 - val_binary_accuracy: 0.6961 - val_false_positives_1: 83.0000 - val_false_negatives_1: 89.0000
# Epoch 94/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4664 - binary_accuracy: 0.7650 - false_positives_1: 177.0000 - false_negatives_1: 355.0000
# Epoch 94: val_loss did not improve from 0.55160
#
# Epoch 94: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4664 - binary_accuracy: 0.7650 - false_positives_1: 177.0000 - false_negatives_1: 355.0000 - val_loss: 0.6550 - val_binary_accuracy: 0.6996 - val_false_positives_1: 76.0000 - val_false_negatives_1: 94.0000
# Epoch 95/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4775 - binary_accuracy: 0.7672 - false_positives_1: 164.0000 - false_negatives_1: 363.0000
# Epoch 95: val_loss did not improve from 0.55160
#
# Epoch 95: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4775 - binary_accuracy: 0.7672 - false_positives_1: 164.0000 - false_negatives_1: 363.0000 - val_loss: 0.6654 - val_binary_accuracy: 0.6996 - val_false_positives_1: 83.0000 - val_false_negatives_1: 87.0000
# Epoch 96/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4658 - binary_accuracy: 0.7659 - false_positives_1: 188.0000 - false_negatives_1: 342.0000
# Epoch 96: val_loss did not improve from 0.55160
#
# Epoch 96: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4658 - binary_accuracy: 0.7659 - false_positives_1: 188.0000 - false_negatives_1: 342.0000 - val_loss: 0.7010 - val_binary_accuracy: 0.7032 - val_false_positives_1: 83.0000 - val_false_negatives_1: 85.0000
# Epoch 97/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4563 - binary_accuracy: 0.7792 - false_positives_1: 183.0000 - false_negatives_1: 317.0000
# Epoch 97: val_loss did not improve from 0.55160
#
# Epoch 97: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4563 - binary_accuracy: 0.7792 - false_positives_1: 183.0000 - false_negatives_1: 317.0000 - val_loss: 0.6994 - val_binary_accuracy: 0.7067 - val_false_positives_1: 75.0000 - val_false_negatives_1: 91.0000
# Epoch 98/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4766 - binary_accuracy: 0.7655 - false_positives_1: 183.0000 - false_negatives_1: 348.0000
# Epoch 98: val_loss did not improve from 0.55160
#
# Epoch 98: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4766 - binary_accuracy: 0.7655 - false_positives_1: 183.0000 - false_negatives_1: 348.0000 - val_loss: 0.6461 - val_binary_accuracy: 0.7032 - val_false_positives_1: 69.0000 - val_false_negatives_1: 99.0000
# Epoch 99/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4655 - binary_accuracy: 0.7734 - false_positives_1: 187.0000 - false_negatives_1: 326.0000
# Epoch 99: val_loss did not improve from 0.55160
#
# Epoch 99: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 204ms/step - loss: 0.4655 - binary_accuracy: 0.7734 - false_positives_1: 187.0000 - false_negatives_1: 326.0000 - val_loss: 0.7100 - val_binary_accuracy: 0.6943 - val_false_positives_1: 87.0000 - val_false_negatives_1: 86.0000
# Epoch 100/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4584 - binary_accuracy: 0.7690 - false_positives_1: 169.0000 - false_negatives_1: 354.0000
# Epoch 100: val_loss did not improve from 0.55160
#
# Epoch 100: val_binary_accuracy did not improve from 0.74558
# 142/142 [==============================] - 29s 205ms/step - loss: 0.4584 - binary_accuracy: 0.7690 - false_positives_1: 169.0000 - false_negatives_1: 354.0000 - val_loss: 0.8015 - val_binary_accuracy: 0.6784 - val_false_positives_1: 101.0000 - val_false_negatives_1: 81.0000
