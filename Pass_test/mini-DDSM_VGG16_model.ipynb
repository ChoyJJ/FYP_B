# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
import os
import numpy as np
from tensorflow.image import resize_with_pad, grayscale_to_rgb
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
# from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Sequential

PATH = "/mnt/d/Datasets/mini-DDSM/"
imgPATH = PATH + "MINI-DDSM-Complete-PNG-16/"
roi_path = PATH + "ROI/"
data_path = PATH + "fullimg/"
save_dir = "/home/jj/FYP/Models/"
image_size = 224
batch_size = 16

gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

os.environ['TF_ENABLE_GPU_GARBAGE_COLLECTION'] = 'false'
# Out:
# 2023-01-31 18:19:09.203797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:09.225555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:09.225591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  roi_path,
  # data_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=batch_size)
  
val_ds = tf.keras.utils.image_dataset_from_directory(
  roi_path,
  # data_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=batch_size)
AUTOTUNE = tf.data.AUTOTUNE
train_ds_aug = train_ds.prefetch(buffer_size=AUTOTUNE).shuffle(1000)
val_ds_aug = val_ds.prefetch(buffer_size=AUTOTUNE).shuffle(1000)
# Out:
# Found 2830 files belonging to 2 classes.
# Using 2264 files for training.
# Found 2830 files belonging to 2 classes.
# Using 566 files for validation.
# 2023-01-31 18:19:13.198081: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 18:19:13.199313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.199355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.199371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.852071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.852134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.852139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-01-31 18:19:13.852163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-01-31 18:19:13.852426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5405 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
preprocessing = preprocess_input
pre_trained = VGG16(weights='imagenet', include_top=False, input_shape=(image_size,image_size,3))
pre_trained.trainable = False
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.),fill_mode="reflect"),
  tf.keras.layers.RandomZoom(height_factor=(-0.5,0.5),width_factor=(-0.5,0.5),fill_mode="reflect"),
  tf.keras.layers.RandomTranslation(height_factor=(-0.25,0.25),width_factor=(-0.25,0.25),fill_mode="reflect")
  ])
#Define model architect
tfinput = Input(shape=(image_size,image_size,3) )
data_augment = data_augmentation(tfinput)
pre_process = preprocessing(data_augment)
vgg16_model=pre_trained(pre_process,training=False)
# flatten = tf.keras.layers.GlobalAveragePooling2D()(resnet50_model)
flatten = Flatten()(vgg16_model)
DO1 = Dropout(0.8)(flatten)
Dense1 = Dense(256,activation = 'relu')(DO1)
x=Dropout(0.7)(Dense1)
x = Dense(128,activation='relu')(x)
DO2 = Dropout(0.7)(x)
output = Dense(1, activation="sigmoid")(DO2)
model = Model(tfinput,output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 21,170,497
# Trainable params: 6,455,809
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate = 1e-4),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.FalseNegatives()]
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq='epoch')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 21,170,497
# Trainable params: 6,455,809
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Training Dense layers to initialise the categoriser before fine tuning the CNN models
total_epochs = 10
dense_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    ,validation_data=val_ds
                    ,callbacks = [cp_callback]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(dense_init.history['loss'])
plt.subplot(132)
plt.plot(dense_init.history['val_loss'])
plt.subplot(133)
plt.plot(dense_init.history['val_binary_accuracy'])
# Out:
# Epoch 1/10
# 2023-01-31 18:19:25.408579: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 16 of 1000
# 2023-01-31 18:19:35.617115: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 41 of 1000
# 2023-01-31 18:19:45.313614: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 64 of 1000
# 2023-01-31 18:19:55.554949: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 90 of 1000
# 2023-01-31 18:20:05.493930: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 115 of 1000
# 2023-01-31 18:20:12.339446: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 2023-01-31 18:20:13.236923: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 2023-01-31 18:20:15.304203: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.304254: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.442302: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.442350: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.558435: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.558480: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.685229: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.22GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.685282: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.22GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:15.755275: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#  17/142 [==>...........................] - ETA: 5s - loss: 7.8992 - binary_accuracy: 0.4816 - false_positives: 65.0000 - false_negatives: 76.0000
# 2023-01-31 18:20:16.568180: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-01-31 18:20:16.568229: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 141/142 [============================>.] - ETA: 0s - loss: 5.3561 - binary_accuracy: 0.4853 - false_positives: 559.0000 - false_negatives: 598.0000
# Epoch 1: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0001.ckpt
# 142/142 [==============================] - 82s 148ms/step - loss: 5.3744 - binary_accuracy: 0.4863 - false_positives: 562.0000 - false_negatives: 601.0000 - val_loss: 0.6729 - val_binary_accuracy: 0.5954 - val_false_positives: 158.0000 - val_false_negatives: 71.0000
# Epoch 2/10
# 142/142 [==============================] - ETA: 0s - loss: 3.6976 - binary_accuracy: 0.4969 - false_positives: 586.0000 - false_negatives: 553.0000
# Epoch 2: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0002.ckpt
# 142/142 [==============================] - 10s 55ms/step - loss: 3.6976 - binary_accuracy: 0.4969 - false_positives: 586.0000 - false_negatives: 553.0000 - val_loss: 0.6713 - val_binary_accuracy: 0.5495 - val_false_positives: 180.0000 - val_false_negatives: 75.0000
# Epoch 3/10
# 142/142 [==============================] - ETA: 0s - loss: 2.5694 - binary_accuracy: 0.5057 - false_positives: 585.0000 - false_negatives: 534.0000
# Epoch 3: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0003.ckpt
# 142/142 [==============================] - 10s 55ms/step - loss: 2.5694 - binary_accuracy: 0.5057 - false_positives: 585.0000 - false_negatives: 534.0000 - val_loss: 0.6792 - val_binary_accuracy: 0.5707 - val_false_positives: 178.0000 - val_false_negatives: 65.0000
# Epoch 4/10
# 141/142 [============================>.] - ETA: 0s - loss: 2.0110 - binary_accuracy: 0.5258 - false_positives: 540.0000 - false_negatives: 526.0000
# Epoch 4: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0004.ckpt
# 142/142 [==============================] - 10s 56ms/step - loss: 2.0069 - binary_accuracy: 0.5256 - false_positives: 543.0000 - false_negatives: 531.0000 - val_loss: 0.6792 - val_binary_accuracy: 0.5636 - val_false_positives: 161.0000 - val_false_negatives: 86.0000
# Epoch 5/10
# 142/142 [==============================] - ETA: 0s - loss: 1.5579 - binary_accuracy: 0.5150 - false_positives: 553.0000 - false_negatives: 545.0000
# Epoch 5: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0005.ckpt
# 142/142 [==============================] - 10s 56ms/step - loss: 1.5579 - binary_accuracy: 0.5150 - false_positives: 553.0000 - false_negatives: 545.0000 - val_loss: 0.6857 - val_binary_accuracy: 0.5972 - val_false_positives: 71.0000 - val_false_negatives: 157.0000
# Epoch 6/10
# 141/142 [============================>.] - ETA: 0s - loss: 1.2694 - binary_accuracy: 0.5187 - false_positives: 540.0000 - false_negatives: 542.0000
# Epoch 6: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0006.ckpt
# 142/142 [==============================] - 10s 55ms/step - loss: 1.2678 - binary_accuracy: 0.5186 - false_positives: 543.0000 - false_negatives: 547.0000 - val_loss: 0.6905 - val_binary_accuracy: 0.5671 - val_false_positives: 35.0000 - val_false_negatives: 210.0000
# Epoch 7/10
# 142/142 [==============================] - ETA: 0s - loss: 1.1387 - binary_accuracy: 0.5040 - false_positives: 559.0000 - false_negatives: 564.0000
# Epoch 7: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0007.ckpt
# 142/142 [==============================] - 10s 56ms/step - loss: 1.1387 - binary_accuracy: 0.5040 - false_positives: 559.0000 - false_negatives: 564.0000 - val_loss: 0.6927 - val_binary_accuracy: 0.5106 - val_false_positives: 2.0000 - val_false_negatives: 275.0000
# Epoch 8/10
# 141/142 [============================>.] - ETA: 0s - loss: 1.0650 - binary_accuracy: 0.5027 - false_positives: 525.0000 - false_negatives: 593.0000
# Epoch 8: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0008.ckpt
# 142/142 [==============================] - 10s 57ms/step - loss: 1.0642 - binary_accuracy: 0.5018 - false_positives: 530.0000 - false_negatives: 598.0000 - val_loss: 0.6931 - val_binary_accuracy: 0.4965 - val_false_positives: 1.0000 - val_false_negatives: 284.0000
# Epoch 9/10
# 142/142 [==============================] - ETA: 0s - loss: 0.9264 - binary_accuracy: 0.5115 - false_positives: 456.0000 - false_negatives: 650.0000
# Epoch 9: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0009.ckpt
# 142/142 [==============================] - 10s 55ms/step - loss: 0.9264 - binary_accuracy: 0.5115 - false_positives: 456.0000 - false_negatives: 650.0000 - val_loss: 0.6931 - val_binary_accuracy: 0.4947 - val_false_positives: 0.0000e+00 - val_false_negatives: 286.0000
# Epoch 10/10
# 141/142 [============================>.] - ETA: 0s - loss: 0.8765 - binary_accuracy: 0.5182 - false_positives: 401.0000 - false_negatives: 682.0000
# Epoch 10: saving model to /home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0010.ckpt
# 142/142 [==============================] - 10s 56ms/step - loss: 0.8769 - binary_accuracy: 0.5186 - false_positives: 406.0000 - false_negatives: 684.0000 - val_loss: 0.6931 - val_binary_accuracy: 0.4947 - val_false_positives: 0.0000e+00 - val_false_negatives: 286.0000

# %%
#load model with best performance
model.load_weights("/home/jj/FYP/Checkpoint/VGG16/dense_init_checkpoint/cp-0004.ckpt")
pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:-12]:
  layer.trainable = False
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate = 1e-5),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.FalseNegatives()]
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/ResNet50/fine_tuning_training_2_checkpoint/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 100
history_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=38
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
