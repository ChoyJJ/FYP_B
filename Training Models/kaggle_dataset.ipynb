# %%
import matplotlib.pyplot as plt
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
import os
from module import Model_Training
import numpy as np

# %%
test_data = np.load('/mnt/c/Users/user/Desktop/CBIS-DDSM_kaggle/cv10_data/cv10_data.npy')
print(test_data.shape)
# Out:
# (7682, 299, 299, 1)

# %%
filename = ['/mnt/c/Users/user/Desktop/CBIS-DDSM_kaggle/training10_0/training10_0.tfrecords']
filenames = [filename]
raw_dataset = tf.data.TFRecordDataset(filenames)
print(raw_dataset.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 4
#       2 filenames = [filename]
#       3 raw_dataset = tf.data.TFRecordDataset(filenames)
# ----> 4 print(raw_dataset.keys())
#
# AttributeError: 'TFRecordDatasetV2' object has no attribute 'keys'

# %%
for raw_record in raw_dataset.take(1):
  example = tf.train.Example()
  example.ParseFromString(raw_record.numpy())
  print(example)
# Out:
# features {
#   feature {
#     key: "filename"
#     value {
#       bytes_list {
#         value: "N\000\000\000O\000\000\000R\000\000\000M\000\000\000A\000\000\000L\000\000\000"
#       }
#     }
#   }
#   feature {
#     key: "image"
#     value {
#       bytes_list {
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 features = tf.compat.v1.parse_single_example(
#       2     raw_dataset,
#       3     features={
#       4         'label': tf.io.FixedLenFeature([], tf.int64),
#       5         'label_normal': tf.io.FixedLenFeature([], tf.int64),
#       6         'image': tf.io.FixedLenFeature([], tf.string)
#       7     })
#       9 # extract the data
#      10 label = features['label_normal']
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# ...
