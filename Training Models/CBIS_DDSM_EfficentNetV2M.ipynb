# %%
import cv2
import matplotlib.pyplot as plt
# import pandas as pd
import tensorflow as tf
import keras
import os
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import regularizers
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M, preprocess_input
# from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Sequential
import shutil
PATH = "/mnt/d/Datasets/"
imgPATH = PATH + "mini-DDSM/MINI-DDSM-Complete-PNG-16/"
ddsm_roi_path = PATH + "CBIS-DDSM/ROI/"
cbis_ddsm_data_path = PATH + 'CBIS-DDSM/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/'
vindr_roi_path = PATH+"/Vindr-Mammo/ROI/"
data_path = PATH + "mini-DDSM/fullimg/"
save_dir = "/home/jj/FYP/Models/"
combined_path = PATH + "combined/"
full_img_path = '/mnt/d/Datasets/CBIS-DDSM/full_mammogram_image/augmented/'
roi_img_path = '/mnt/d/Datasets/CBIS-DDSM/ROI/augmented/'
image_size = 300
img_height = 300
img_width = 300
batch_size = 16
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

os.environ['TF_ENABLE_GPU_GARBAGE_COLLECTION'] = 'false'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2023-02-14 03:06:26.036545: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-14 03:06:26.550278: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jj/miniconda3/envs/tf/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda/include:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64::/usr/local/cuda/extras/CUPTI/lib64:/home/jj/miniconda3/envs/tf/lib/
# 2023-02-14 03:06:26.550351: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jj/miniconda3/envs/tf/lib/python3.9/site-packages/cv2/../../lib64:/usr/local/cuda/include:/usr/local/cuda/lib64:/usr/local/cuda-11.2/lib64::/usr/local/cuda/extras/CUPTI/lib64:/home/jj/miniconda3/envs/tf/lib/
# 2023-02-14 03:06:26.550356: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# 2023-02-14 03:06:27.146965: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:27.157002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:27.157057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %% [markdown]
# # load ddsm

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  roi_img_path+'train/',
  label_mode="categorical",
  # validation_split=0.2,
  # subset="training",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
  
val_ds = tf.keras.utils.image_dataset_from_directory(
  roi_img_path+'val/',
  label_mode="categorical",
  # validation_split=0.2,
  # subset="validation",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2088 files belonging to 2 classes.
# 2023-02-14 03:06:31.382581: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-14 03:06:31.383387: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.383448: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.383465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.941918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.942006: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.942012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-02-14 03:06:31.942033: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-02-14 03:06:31.942064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4547 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 776 files belonging to 2 classes.

# %%
class_indices = {'class_1': 0, 'class_2': 1}
class_counts = np.zeros((len(class_indices),))
for images, labels in val_ds:
    # print(labels[0])
    for l in labels:
        if l[0] == 1:
            class_counts[0]+=1
        elif l[1] == 1:
            class_counts[1]+=1
        
print('Number of images used from each category:')
for class_name, class_index in class_indices.items():
    print(f'{class_name}: {class_counts[class_index]}')
# Out:
# Number of images used from each category:
# class_1: 714.0
# class_2: 62.0

# %%
preprocessing = preprocess_input
pre_trained = EfficientNetV2M(weights='imagenet', include_top=False, input_shape=(img_height,img_width,3))
pre_trained.trainable = False
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.2),fill_mode='constant'),
  tf.keras.layers.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2),fill_mode='constant'),
  tf.keras.layers.RandomTranslation(height_factor=(-0.1,0.1),width_factor=(-0.1,0.1),fill_mode='constant')
  ])
#Define model architect
tfinput = Input(shape=(img_height,img_width,3))
data_augment = data_augmentation(tfinput)
pre_process = preprocessing(data_augment)
eff_net_v2m=pre_trained(pre_process,training=False)
# flatten = tf.keras.layers.GlobalAveragePooling2D()(eff_net_v2m)
flatten = tf.keras.layers.Flatten()(eff_net_v2m)
# DO1 = Dropout(0.8)(flatten)
# x = Dense(1024,activation = 'relu')(flatten)
# x = Dense(512,activation='relu')(x)
x = Dense(8,activation = 'relu')(flatten)
x = Dense(8,activation='relu')(x)
x=Dropout(0.5)(x)
# x = Dense(512,activation='relu',kernel_regularizer=regularizers.l2(0.1))(x)
x = Dense(8,activation='relu')(x)
# ,kernel_regularizer=regularizers.l2(0.1))(x)
# output = Dense(1, activation="sigmoid")(DO2)
output = Dense(2, activation="softmax")(x)
model = Model(tfinput,output)
model.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 300, 300, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 300, 300, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 8)                 1048584
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 22,851,530
# Trainable params: 1,048,746
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# @tf.function
AUTOTUNE = tf.data.AUTOTUNE
def fetch(data):
    # data=data.cache()
    data = data.batch(4)
    data=data.prefetch(buffer_size=AUTOTUNE)
    return data

# %%
train_ds_aug = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds_aug= val_ds.prefetch(buffer_size=AUTOTUNE)

# train_ds_aug = fetch(train_ds)
# val_ds_aug= fetch(val_ds)

# %%
class PrintLR(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = tf.keras.backend.get_value(self.model.optimizer.lr)
        print(
            # f'Epoch {epoch}: accuracy={logs["categorical_accuracy"]:.4f}, loss={logs["loss"]:.4f}, '+
            # f'val_accuracy={logs["val_categorical_accuracy"]:.4f}, val_loss={logs["val_loss"]:.4f}, '+
            f' - lr={lr:.7f}')

# %% [markdown]
# # initialising

# %%
optimiser_Adam = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(
    optimizer= optimiser_Adam,
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(class_id=0),tf.keras.metrics.Precision(class_id=1)]
    # ,jit_compile=True
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/dense_init_checkpoint/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_categorical_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 300, 300, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 300, 300, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 8)                 1048584
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 22,851,530
# Trainable params: 1,048,746
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
#Training Dense layers to initialise the categoriser before fine tuning the CNN models
best_weights = None
best_val_loss = float('inf')
best_val_acc=float(0)
all_history = {}
all_history['train_loss'] = []
all_history['train_acc'] = []
all_history['val_loss'] = []
all_history['val_acc'] = []
min_lr = 1e-5
with tf.device('/GPU:0'):
    total_epochs=20
    for i in range(total_epochs):
        # print("Epoch: {}".format(i))
        history = model.fit(train_ds_aug
                            ,epochs=i+1
                            ,initial_epoch=i
                            ,validation_data=val_ds_aug
                            ,callbacks = [PrintLR()]
                            # ,verbose=0
                            )
        # print("Learning rate: {}".format(optimiser_Adam.lr.numpy()))
        val_loss = history.history['val_loss'][-1]
        val_categorical_accuracy = history.history['val_categorical_accuracy'][-1]
        loss = history.history['loss'][-1]
        categorical_accuracy = history.history['categorical_accuracy'][-1]
        all_history['train_loss'].append(loss)
        all_history['train_acc'].append(categorical_accuracy)
        all_history['val_loss'].append(val_loss)
        all_history['val_acc'].append(val_categorical_accuracy)
        patience = 20
        # val_improve = val_loss<best_val_loss and
        if val_loss < best_val_loss:
            best_weights = model.get_weights()
            model.save_weights("/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/dense_init_checkpoint/best_model")
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1

        # Check if we have reached the patience limit
        if patience_counter == patience:
            # Load the best weights back into the model
            model.set_weights(best_weights)
            # Reduce the learning rate
            if optimiser_Adam.lr > min_lr:
                optimiser_Adam.lr = optimiser_Adam.lr * 0.1
            # Reset the patience counter
            patience_counter = 0
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(all_history['train_loss'])
plt.subplot(132)
plt.plot(all_history['val_loss'])
plt.subplot(133)
plt.plot(all_history['val_categorical_accuracy'])
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-02-14 00:24:43.140594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-02-14 00:24:45.188409: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:24:45.188454: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:24:45.690543: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:24:45.690586: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:24:45.713064: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-02-14 00:24:45.726853: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fed60019c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-14 00:24:45.726880: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti, Compute Capability 8.6
# 2023-02-14 00:24:45.743893: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-14 00:24:45.911036: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 358/358 [==============================] - ETA: 0s - loss: 1.2927 - categorical_accuracy: 0.5151 - precision: 0.5166 - precision_1: 0.5115
# 2023-02-14 00:25:58.879961: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:25:58.880027: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:26:02.689408: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:26:02.689457: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  - lr=0.0100000
# 358/358 [==============================] - 86s 215ms/step - loss: 1.2927 - categorical_accuracy: 0.5151 - precision: 0.5166 - precision_1: 0.5115 - val_loss: 0.7010 - val_categorical_accuracy: 0.5733 - val_precision: 0.6521 - val_precision_1: 0.4623
# 2023-02-14 00:26:03.170610: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-14 00:26:03.170656: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Epoch 2/2
# 358/358 [==============================] - ETA: 0s - loss: 0.6943 - categorical_accuracy: 0.5008 - precision: 0.5051 - precision_1: 0.4645 - lr=0.0100000
# 358/358 [==============================] - 75s 209ms/step - loss: 0.6943 - categorical_accuracy: 0.5008 - precision: 0.5051 - precision_1: 0.4645 - val_loss: 0.6937 - val_categorical_accuracy: 0.4053 - val_precision: 0.5353 - val_precision_1: 0.3841
# Epoch 3/3
# 358/358 [==============================] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.4959 - precision: 0.5026 - precision_1: 0.4678 - lr=0.0100000
# 358/358 [==============================] - 74s 208ms/step - loss: 0.6938 - categorical_accuracy: 0.4959 - precision: 0.5026 - precision_1: 0.4678 - val_loss: 0.6938 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 4/4
# 358/358 [==============================] - ETA: 0s - loss: 0.6937 - categorical_accuracy: 0.4933 - precision: 0.5011 - precision_1: 0.4742 - lr=0.0100000
# 358/358 [==============================] - 74s 206ms/step - loss: 0.6937 - categorical_accuracy: 0.4933 - precision: 0.5011 - precision_1: 0.4742 - val_loss: 0.6934 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 5/5
# 358/358 [==============================] - ETA: 0s - loss: 0.6937 - categorical_accuracy: 0.4997 - precision: 0.5059 - precision_1: 0.4867 - lr=0.0100000
# 358/358 [==============================] - 73s 205ms/step - loss: 0.6937 - categorical_accuracy: 0.4997 - precision: 0.5059 - precision_1: 0.4867 - val_loss: 0.6952 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 6/6
# 358/358 [==============================] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.4929 - precision: 0.5009 - precision_1: 0.4738 - lr=0.0100000
# 358/358 [==============================] - 73s 203ms/step - loss: 0.6938 - categorical_accuracy: 0.4929 - precision: 0.5009 - precision_1: 0.4738 - val_loss: 0.6913 - val_categorical_accuracy: 0.6046 - val_precision: 0.6046 - val_precision_1: 0.0000e+00
# Epoch 7/7
# 358/358 [==============================] - ETA: 0s - loss: 0.6935 - categorical_accuracy: 0.5039 - precision: 0.5078 - precision_1: 0.4898 - lr=0.0100000
# 358/358 [==============================] - 73s 205ms/step - loss: 0.6935 - categorical_accuracy: 0.5039 - precision: 0.5078 - precision_1: 0.4898 - val_loss: 0.6942 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 8/8
# 358/358 [==============================] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.4948 - precision: 0.5022 - precision_1: 0.4750 - lr=0.0100000
# 358/358 [==============================] - 73s 203ms/step - loss: 0.6938 - categorical_accuracy: 0.4948 - precision: 0.5022 - precision_1: 0.4750 - val_loss: 0.6949 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 9/9
# 358/358 [==============================] - ETA: 0s - loss: 0.6937 - categorical_accuracy: 0.4961 - precision: 0.5028 - precision_1: 0.4708 - lr=0.0100000
# 358/358 [==============================] - 72s 201ms/step - loss: 0.6937 - categorical_accuracy: 0.4961 - precision: 0.5028 - precision_1: 0.4708 - val_loss: 0.6919 - val_categorical_accuracy: 0.6046 - val_precision: 0.6046 - val_precision_1: 0.0000e+00
# Epoch 10/10
# 358/358 [==============================] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.4924 - precision: 0.5005 - precision_1: 0.4728 - lr=0.0100000
# 358/358 [==============================] - 73s 204ms/step - loss: 0.6938 - categorical_accuracy: 0.4924 - precision: 0.5005 - precision_1: 0.4728 - val_loss: 0.6952 - val_categorical_accuracy: 0.3954 - val_precision: 0.0000e+00 - val_precision_1: 0.3954
# Epoch 11/11
# 358/358 [==============================] - ETA: 0s - loss: 0.6935 - categorical_accuracy: 0.4992 - precision: 0.5051 - precision_1: 0.4827 - lr=0.0100000
# 358/358 [==============================] - 75s 209ms/step - loss: 0.6935 - categorical_accuracy: 0.4992 - precision: 0.5051 - precision_1: 0.4827 - val_loss: 0.6928 - val_categorical_accuracy: 0.6046 - val_precision: 0.6046 - val_precision_1: 0.0000e+00
# Epoch 12/12
# 198/358 [===============>..............] - ETA: 31s - loss: 0.6930 - categorical_accuracy: 0.5133 - precision: 0.5133 - precision_1: 0.0000e+00

# %% [markdown]
# # fine tuning

# %%
preprocessing = preprocess_input
pre_trained = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_height,img_width,3))
pre_trained.trainable = False
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.2),fill_mode='constant'),
  tf.keras.layers.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2),fill_mode='constant'),
  tf.keras.layers.RandomTranslation(height_factor=(-0.1,0.1),width_factor=(-0.1,0.1),fill_mode='constant')
  ])
#Define model architect
pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:-63]:
  layer.trainable = False
tfinput = Input(shape=(img_height,img_width,3))
data_augment = data_augmentation(tfinput)
pre_process = preprocessing(data_augment)
inceptionv3_model=pre_trained(pre_process,training=False)
# flatten = tf.keras.layers.GlobalAveragePooling2D()(inceptionv3_model)
flatten = tf.keras.layers.Flatten()(inceptionv3_model)
# DO1 = Dropout(0.8)(flatten)
# x = Dense(1024,activation = 'relu')(flatten)
# x = Dense(512,activation='relu')(x)
x = Dense(8,activation = 'relu')(flatten)
x = Dense(8,activation='relu')(x)
x=Dropout(0.5)(x)
# x = Dense(512,activation='relu',kernel_regularizer=regularizers.l2(0.1))(x)
x = Dense(8,activation='relu',kernel_regularizer=regularizers.l2(0.1))(x)
# output = Dense(1, activation="sigmoid")(DO2)
output = Dense(2, activation="softmax")(x)
model_fine = Model(tfinput,output)
model_fine.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential_1 (Sequential)   (None, 300, 300, 3)       0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 300, 300, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 300, 300, 3)      0
#  bda)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 8)                 16392
#
#  dense_5 (Dense)             (None, 8)                 72
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 21,819,338
# Trainable params: 11,124,906
# Non-trainable params: 10,694,432
# _________________________________________________________________

# %%
#load model_fine with best performance
# model_fine.load_weights("/home/jj/FYP/Checkpoint/EfficientNet/dense_init_checkpoint/cp-0010.ckpt")
# tf.keras.backend.clear_session()
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/dense_init_checkpoint')
model_fine.load_weights(latest)
# model_fine.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/fine_tuning_checkpoint_loss/cp-{epoch:04d}.ckpt"
# cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    # filepath=checkpoint_path, 
    # verbose=1, 
    # monitor='val_loss',
    # save_best_only=True,
    # save_weights_only=True,
    # save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/fine_tuning_checkpoint_acc/cp-{epoch:04d}.ckpt"
# cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    # filepath=checkpoint_path_2, 
    # verbose=1, 
    # monitor='val_categorical_accuracy',
    # save_best_only=True,
    # save_weights_only=True,
    # save_freq='epoch')
optimiser = tf.keras.optimizers.legacy.SGD(learning_rate=0.001)
model_fine.compile(
    optimizer= optimiser,
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(class_id=0),tf.keras.metrics.Precision(class_id=1)]
)
# reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5,min_lr=1e-6,verbose=1)
best_weights = None
best_val_loss = float('inf')
best_val_acc=float(0)
all_history = {}
all_history['train_loss'] = []
all_history['train_acc'] = []
all_history['val_loss'] = []
all_history['val_acc'] = []
min_lr = 1e-7
with tf.device('/GPU:0'):
    total_epochs=100
    for i in range(total_epochs):
        # print("Epoch: {}".format(i))
        history = model_fine.fit(train_ds_aug
                            ,epochs=i+1
                            ,initial_epoch=i
                            ,validation_data=val_ds_aug
                            ,callbacks = [PrintLR()]
                            # ,verbose=0
                            )
        # print("Learning rate: {}".format(optimiser.lr.numpy()))
        val_loss = history.history['val_loss'][-1]
        val_categorical_accuracy = history.history['val_categorical_accuracy'][-1]
        loss = history.history['loss'][-1]
        categorical_accuracy = history.history['categorical_accuracy'][-1]
        all_history['train_loss'].append(loss)
        all_history['train_acc'].append(categorical_accuracy)
        all_history['val_loss'].append(val_loss)
        all_history['val_acc'].append(val_categorical_accuracy)
        patience = 5
        # val_improve = val_loss<best_val_loss and
        if val_loss < best_val_loss:
            best_weights = model_fine.get_weights()
            model_fine.save_weights("/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/fine_tuning_checkpoint_loss/best_model")
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1

        # Check if we have reached the patience limit
        if patience_counter == patience:
            # Load the best weights back into the model_fine
            model_fine.set_weights(best_weights)
            # Reduce the learning rate
            if optimiser.lr > min_lr:
                optimiser.lr = optimiser.lr * 0.1
            # Reset the patience counter
            patience_counter = 0
# model_fine.set_weights(best_weights)
# model_fine.save_weights("/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi/fine_tuning_checkpoint_loss/best_model")

plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(all_history['train_loss'])
plt.subplot(132)
plt.plot(all_history['val_loss'])
plt.subplot(133)
plt.plot(all_history['val_acc'])
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-02-13 19:37:34.851755: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-02-13 19:37:35.984359: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:37:35.984407: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:37:36.468950: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:37:36.468994: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:37:36.514306: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   1/349 [..............................] - ETA: 44:26 - loss: 1.4805 - categorical_accuracy: 0.7500 - precision: 0.8333 - precision_1: 0.7000
# 2023-02-13 19:37:36.818402: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:37:36.818448: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 348/349 [============================>.] - ETA: 0s - loss: 1.3965 - categorical_accuracy: 0.5957 - precision: 0.6433 - precision_1: 0.5768
# 2023-02-13 19:38:44.004114: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:38:44.004159: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:38:44.456325: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-02-13 19:38:44.456370: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 349/349 [==============================] - ETA: 0s - loss: 1.3962 - categorical_accuracy: 0.5962 - precision: 0.6447 - precision_1: 0.5769lr=0.0010000
# 349/349 [==============================] - 80s 207ms/step - loss: 1.3962 - categorical_accuracy: 0.5962 - precision: 0.6447 - precision_1: 0.5769 - val_loss: 1.2886 - val_categorical_accuracy: 0.6770 - val_precision: 0.7754 - val_precision_1: 0.5702
# Epoch 2/2
# 349/349 [==============================] - ETA: 0s - loss: 1.2982 - categorical_accuracy: 0.5985 - precision: 0.6431 - precision_1: 0.5798lr=0.0010000
# 349/349 [==============================] - 70s 200ms/step - loss: 1.2982 - categorical_accuracy: 0.5985 - precision: 0.6431 - precision_1: 0.5798 - val_loss: 1.1899 - val_categorical_accuracy: 0.6964 - val_precision: 0.7622 - val_precision_1: 0.6040
# Epoch 3/3
# 349/349 [==============================] - ETA: 0s - loss: 1.2083 - categorical_accuracy: 0.6093 - precision: 0.6505 - precision_1: 0.5901lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 1.2083 - categorical_accuracy: 0.6093 - precision: 0.6505 - precision_1: 0.5901 - val_loss: 1.1216 - val_categorical_accuracy: 0.6661 - val_precision: 0.7982 - val_precision_1: 0.5524
# Epoch 4/4
# 349/349 [==============================] - ETA: 0s - loss: 1.1373 - categorical_accuracy: 0.5998 - precision: 0.6367 - precision_1: 0.5829lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 1.1373 - categorical_accuracy: 0.5998 - precision: 0.6367 - precision_1: 0.5829 - val_loss: 1.0342 - val_categorical_accuracy: 0.7090 - val_precision: 0.7578 - val_precision_1: 0.6300
# Epoch 5/5
# 349/349 [==============================] - ETA: 0s - loss: 1.0704 - categorical_accuracy: 0.6093 - precision: 0.6556 - precision_1: 0.5888lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 1.0704 - categorical_accuracy: 0.6093 - precision: 0.6556 - precision_1: 0.5888 - val_loss: 0.9828 - val_categorical_accuracy: 0.6922 - val_precision: 0.7827 - val_precision_1: 0.5884
# Epoch 6/6
# 349/349 [==============================] - ETA: 0s - loss: 1.0081 - categorical_accuracy: 0.6179 - precision: 0.6520 - precision_1: 0.6001lr=0.0010000
# 349/349 [==============================] - 71s 204ms/step - loss: 1.0081 - categorical_accuracy: 0.6179 - precision: 0.6520 - precision_1: 0.6001 - val_loss: 0.9318 - val_categorical_accuracy: 0.6703 - val_precision: 0.8055 - val_precision_1: 0.5559
# Epoch 7/7
# 349/349 [==============================] - ETA: 0s - loss: 0.9575 - categorical_accuracy: 0.6211 - precision: 0.6579 - precision_1: 0.6022lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.9575 - categorical_accuracy: 0.6211 - precision: 0.6579 - precision_1: 0.6022 - val_loss: 0.8806 - val_categorical_accuracy: 0.6871 - val_precision: 0.8048 - val_precision_1: 0.5754
# Epoch 8/8
# 349/349 [==============================] - ETA: 0s - loss: 0.9125 - categorical_accuracy: 0.6322 - precision: 0.6640 - precision_1: 0.6142lr=0.0010000
# 349/349 [==============================] - 75s 214ms/step - loss: 0.9125 - categorical_accuracy: 0.6322 - precision: 0.6640 - precision_1: 0.6142 - val_loss: 0.8326 - val_categorical_accuracy: 0.7124 - val_precision: 0.7693 - val_precision_1: 0.6276
# Epoch 9/9
# 349/349 [==============================] - ETA: 0s - loss: 0.8777 - categorical_accuracy: 0.6233 - precision: 0.6580 - precision_1: 0.6048lr=0.0010000
# 349/349 [==============================] - 73s 208ms/step - loss: 0.8777 - categorical_accuracy: 0.6233 - precision: 0.6580 - precision_1: 0.6048 - val_loss: 0.8013 - val_categorical_accuracy: 0.6964 - val_precision: 0.7741 - val_precision_1: 0.5981
# Epoch 10/10
# 349/349 [==============================] - ETA: 0s - loss: 0.8427 - categorical_accuracy: 0.6215 - precision: 0.6579 - precision_1: 0.6026lr=0.0010000
# 349/349 [==============================] - 71s 204ms/step - loss: 0.8427 - categorical_accuracy: 0.6215 - precision: 0.6579 - precision_1: 0.6026 - val_loss: 0.7631 - val_categorical_accuracy: 0.7183 - val_precision: 0.7552 - val_precision_1: 0.6518
# Epoch 11/11
# 349/349 [==============================] - ETA: 0s - loss: 0.8157 - categorical_accuracy: 0.6327 - precision: 0.6687 - precision_1: 0.6132lr=0.0010000
# 349/349 [==============================] - 72s 206ms/step - loss: 0.8157 - categorical_accuracy: 0.6327 - precision: 0.6687 - precision_1: 0.6132 - val_loss: 0.7439 - val_categorical_accuracy: 0.7115 - val_precision: 0.7817 - val_precision_1: 0.6184
# Epoch 12/12
# 349/349 [==============================] - ETA: 0s - loss: 0.7883 - categorical_accuracy: 0.6333 - precision: 0.6682 - precision_1: 0.6141lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.7883 - categorical_accuracy: 0.6333 - precision: 0.6682 - precision_1: 0.6141 - val_loss: 0.7198 - val_categorical_accuracy: 0.7098 - val_precision: 0.7888 - val_precision_1: 0.6121
# Epoch 13/13
# 349/349 [==============================] - ETA: 0s - loss: 0.7681 - categorical_accuracy: 0.6306 - precision: 0.6703 - precision_1: 0.6099lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.7681 - categorical_accuracy: 0.6306 - precision: 0.6703 - precision_1: 0.6099 - val_loss: 0.7199 - val_categorical_accuracy: 0.6636 - val_precision: 0.8168 - val_precision_1: 0.5473
# Epoch 14/14
# 349/349 [==============================] - ETA: 0s - loss: 0.7448 - categorical_accuracy: 0.6338 - precision: 0.6621 - precision_1: 0.6172lr=0.0010000
# 349/349 [==============================] - 71s 204ms/step - loss: 0.7448 - categorical_accuracy: 0.6338 - precision: 0.6621 - precision_1: 0.6172 - val_loss: 0.6838 - val_categorical_accuracy: 0.7082 - val_precision: 0.7864 - val_precision_1: 0.6106
# Epoch 15/15
# 349/349 [==============================] - ETA: 0s - loss: 0.7285 - categorical_accuracy: 0.6439 - precision: 0.6727 - precision_1: 0.6264lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.7285 - categorical_accuracy: 0.6439 - precision: 0.6727 - precision_1: 0.6264 - val_loss: 0.6706 - val_categorical_accuracy: 0.7048 - val_precision: 0.7931 - val_precision_1: 0.6025
# Epoch 16/16
# 349/349 [==============================] - ETA: 0s - loss: 0.7184 - categorical_accuracy: 0.6317 - precision: 0.6594 - precision_1: 0.6154lr=0.0010000
# 349/349 [==============================] - 71s 204ms/step - loss: 0.7184 - categorical_accuracy: 0.6317 - precision: 0.6594 - precision_1: 0.6154 - val_loss: 0.6574 - val_categorical_accuracy: 0.7115 - val_precision: 0.7894 - val_precision_1: 0.6144
# Epoch 17/17
# 349/349 [==============================] - ETA: 0s - loss: 0.7023 - categorical_accuracy: 0.6403 - precision: 0.6734 - precision_1: 0.6213lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.7023 - categorical_accuracy: 0.6403 - precision: 0.6734 - precision_1: 0.6213 - val_loss: 0.6429 - val_categorical_accuracy: 0.7115 - val_precision: 0.7868 - val_precision_1: 0.6157
# Epoch 18/18
# 349/349 [==============================] - ETA: 0s - loss: 0.6894 - categorical_accuracy: 0.6379 - precision: 0.6675 - precision_1: 0.6206lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6894 - categorical_accuracy: 0.6379 - precision: 0.6675 - precision_1: 0.6206 - val_loss: 0.6305 - val_categorical_accuracy: 0.7140 - val_precision: 0.7860 - val_precision_1: 0.6202
# Epoch 19/19
# 349/349 [==============================] - ETA: 0s - loss: 0.6835 - categorical_accuracy: 0.6340 - precision: 0.6594 - precision_1: 0.6186lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6835 - categorical_accuracy: 0.6340 - precision: 0.6594 - precision_1: 0.6186 - val_loss: 0.6224 - val_categorical_accuracy: 0.7090 - val_precision: 0.7833 - val_precision_1: 0.6135
# Epoch 20/20
# 349/349 [==============================] - ETA: 0s - loss: 0.6673 - categorical_accuracy: 0.6462 - precision: 0.6726 - precision_1: 0.6298lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6673 - categorical_accuracy: 0.6462 - precision: 0.6726 - precision_1: 0.6298 - val_loss: 0.6189 - val_categorical_accuracy: 0.7107 - val_precision: 0.7944 - val_precision_1: 0.6107
# Epoch 21/21
# 349/349 [==============================] - ETA: 0s - loss: 0.6668 - categorical_accuracy: 0.6430 - precision: 0.6761 - precision_1: 0.6238lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6668 - categorical_accuracy: 0.6430 - precision: 0.6761 - precision_1: 0.6238 - val_loss: 0.6034 - val_categorical_accuracy: 0.7174 - val_precision: 0.7775 - val_precision_1: 0.6311
# Epoch 22/22
# 349/349 [==============================] - ETA: 0s - loss: 0.6534 - categorical_accuracy: 0.6458 - precision: 0.6832 - precision_1: 0.6248lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6534 - categorical_accuracy: 0.6458 - precision: 0.6832 - precision_1: 0.6248 - val_loss: 0.6030 - val_categorical_accuracy: 0.7107 - val_precision: 0.7882 - val_precision_1: 0.6136
# Epoch 23/23
# 349/349 [==============================] - ETA: 0s - loss: 0.6556 - categorical_accuracy: 0.6435 - precision: 0.6780 - precision_1: 0.6237lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6556 - categorical_accuracy: 0.6435 - precision: 0.6780 - precision_1: 0.6237 - val_loss: 0.5966 - val_categorical_accuracy: 0.7216 - val_precision: 0.7782 - val_precision_1: 0.6383
# Epoch 24/24
# 349/349 [==============================] - ETA: 0s - loss: 0.6460 - categorical_accuracy: 0.6431 - precision: 0.6744 - precision_1: 0.6247lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6460 - categorical_accuracy: 0.6431 - precision: 0.6744 - precision_1: 0.6247 - val_loss: 0.5867 - val_categorical_accuracy: 0.7317 - val_precision: 0.7736 - val_precision_1: 0.6622
# Epoch 25/25
# 349/349 [==============================] - ETA: 0s - loss: 0.6440 - categorical_accuracy: 0.6482 - precision: 0.6794 - precision_1: 0.6294lr=0.0010000
# 349/349 [==============================] - 70s 200ms/step - loss: 0.6440 - categorical_accuracy: 0.6482 - precision: 0.6794 - precision_1: 0.6294 - val_loss: 0.5820 - val_categorical_accuracy: 0.7250 - val_precision: 0.7314 - val_precision_1: 0.7082
# Epoch 26/26
# 349/349 [==============================] - ETA: 0s - loss: 0.6396 - categorical_accuracy: 0.6413 - precision: 0.6733 - precision_1: 0.6227lr=0.0010000
# 349/349 [==============================] - 70s 200ms/step - loss: 0.6396 - categorical_accuracy: 0.6413 - precision: 0.6733 - precision_1: 0.6227 - val_loss: 0.5847 - val_categorical_accuracy: 0.7258 - val_precision: 0.7692 - val_precision_1: 0.6540
# Epoch 27/27
# 349/349 [==============================] - ETA: 0s - loss: 0.6322 - categorical_accuracy: 0.6489 - precision: 0.6832 - precision_1: 0.6288lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6322 - categorical_accuracy: 0.6489 - precision: 0.6832 - precision_1: 0.6288 - val_loss: 0.5957 - val_categorical_accuracy: 0.7014 - val_precision: 0.8013 - val_precision_1: 0.5948
# Epoch 28/28
# 349/349 [==============================] - ETA: 0s - loss: 0.6236 - categorical_accuracy: 0.6544 - precision: 0.6856 - precision_1: 0.6354lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6236 - categorical_accuracy: 0.6544 - precision: 0.6856 - precision_1: 0.6354 - val_loss: 0.5890 - val_categorical_accuracy: 0.6972 - val_precision: 0.7987 - val_precision_1: 0.5900
# Epoch 29/29
# 349/349 [==============================] - ETA: 0s - loss: 0.6237 - categorical_accuracy: 0.6537 - precision: 0.6942 - precision_1: 0.6309lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6237 - categorical_accuracy: 0.6537 - precision: 0.6942 - precision_1: 0.6309 - val_loss: 0.5730 - val_categorical_accuracy: 0.7241 - val_precision: 0.7800 - val_precision_1: 0.6417
# Epoch 30/30
# 349/349 [==============================] - ETA: 0s - loss: 0.6249 - categorical_accuracy: 0.6471 - precision: 0.6804 - precision_1: 0.6276lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6249 - categorical_accuracy: 0.6471 - precision: 0.6804 - precision_1: 0.6276 - val_loss: 0.5769 - val_categorical_accuracy: 0.7140 - val_precision: 0.7975 - val_precision_1: 0.6144
# Epoch 31/31
# 349/349 [==============================] - ETA: 0s - loss: 0.6222 - categorical_accuracy: 0.6539 - precision: 0.6862 - precision_1: 0.6344lr=0.0010000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6222 - categorical_accuracy: 0.6539 - precision: 0.6862 - precision_1: 0.6344 - val_loss: 0.5811 - val_categorical_accuracy: 0.7040 - val_precision: 0.8042 - val_precision_1: 0.5972
# Epoch 32/32
# 349/349 [==============================] - ETA: 0s - loss: 0.6200 - categorical_accuracy: 0.6499 - precision: 0.6811 - precision_1: 0.6312lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6200 - categorical_accuracy: 0.6499 - precision: 0.6811 - precision_1: 0.6312 - val_loss: 0.5796 - val_categorical_accuracy: 0.7031 - val_precision: 0.8059 - val_precision_1: 0.5955
# Epoch 33/33
# 349/349 [==============================] - ETA: 0s - loss: 0.6204 - categorical_accuracy: 0.6460 - precision: 0.6854 - precision_1: 0.6242lr=0.0010000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6204 - categorical_accuracy: 0.6460 - precision: 0.6854 - precision_1: 0.6242 - val_loss: 0.5897 - val_categorical_accuracy: 0.6955 - val_precision: 0.8235 - val_precision_1: 0.5812
# Epoch 34/34
# 349/349 [==============================] - ETA: 0s - loss: 0.6173 - categorical_accuracy: 0.6510 - precision: 0.6876 - precision_1: 0.6299lr=0.0010000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6173 - categorical_accuracy: 0.6510 - precision: 0.6876 - precision_1: 0.6299 - val_loss: 0.5923 - val_categorical_accuracy: 0.6846 - val_precision: 0.8241 - val_precision_1: 0.5686
# Epoch 35/35
# 349/349 [==============================] - ETA: 0s - loss: 0.6160 - categorical_accuracy: 0.6591 - precision: 0.6971 - precision_1: 0.6369lr=0.0001000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6160 - categorical_accuracy: 0.6591 - precision: 0.6971 - precision_1: 0.6369 - val_loss: 0.5657 - val_categorical_accuracy: 0.7309 - val_precision: 0.7606 - val_precision_1: 0.6748
# Epoch 36/36
# 349/349 [==============================] - ETA: 0s - loss: 0.6125 - categorical_accuracy: 0.6618 - precision: 0.6987 - precision_1: 0.6398lr=0.0001000
# 349/349 [==============================] - 72s 207ms/step - loss: 0.6125 - categorical_accuracy: 0.6618 - precision: 0.6987 - precision_1: 0.6398 - val_loss: 0.5644 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 37/37
# 349/349 [==============================] - ETA: 0s - loss: 0.6135 - categorical_accuracy: 0.6607 - precision: 0.6919 - precision_1: 0.6413lr=0.0001000
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6135 - categorical_accuracy: 0.6607 - precision: 0.6919 - precision_1: 0.6413 - val_loss: 0.5655 - val_categorical_accuracy: 0.7292 - val_precision: 0.7683 - val_precision_1: 0.6621
# Epoch 38/38
# 349/349 [==============================] - ETA: 0s - loss: 0.6109 - categorical_accuracy: 0.6666 - precision: 0.6972 - precision_1: 0.6473lr=0.0001000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6109 - categorical_accuracy: 0.6666 - precision: 0.6972 - precision_1: 0.6473 - val_loss: 0.5635 - val_categorical_accuracy: 0.7359 - val_precision: 0.7658 - val_precision_1: 0.6803
# Epoch 39/39
# 349/349 [==============================] - ETA: 0s - loss: 0.6130 - categorical_accuracy: 0.6673 - precision: 0.6956 - precision_1: 0.6491lr=0.0001000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6130 - categorical_accuracy: 0.6673 - precision: 0.6956 - precision_1: 0.6491 - val_loss: 0.5663 - val_categorical_accuracy: 0.7283 - val_precision: 0.7709 - val_precision_1: 0.6577
# Epoch 40/40
# 349/349 [==============================] - ETA: 0s - loss: 0.6113 - categorical_accuracy: 0.6662 - precision: 0.6997 - precision_1: 0.6456lr=0.0001000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6113 - categorical_accuracy: 0.6662 - precision: 0.6997 - precision_1: 0.6456 - val_loss: 0.5656 - val_categorical_accuracy: 0.7300 - val_precision: 0.7701 - val_precision_1: 0.6621
# Epoch 41/41
# 349/349 [==============================] - ETA: 0s - loss: 0.6116 - categorical_accuracy: 0.6636 - precision: 0.7017 - precision_1: 0.6410lr=0.0001000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6116 - categorical_accuracy: 0.6636 - precision: 0.7017 - precision_1: 0.6410 - val_loss: 0.5662 - val_categorical_accuracy: 0.7241 - val_precision: 0.7701 - val_precision_1: 0.6498
# Epoch 42/42
# 349/349 [==============================] - ETA: 0s - loss: 0.6111 - categorical_accuracy: 0.6697 - precision: 0.7101 - precision_1: 0.6458lr=0.0001000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6111 - categorical_accuracy: 0.6697 - precision: 0.7101 - precision_1: 0.6458 - val_loss: 0.5666 - val_categorical_accuracy: 0.7241 - val_precision: 0.7761 - val_precision_1: 0.6447
# Epoch 43/43
# 349/349 [==============================] - ETA: 0s - loss: 0.6101 - categorical_accuracy: 0.6688 - precision: 0.7082 - precision_1: 0.6454lr=0.0001000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6101 - categorical_accuracy: 0.6688 - precision: 0.7082 - precision_1: 0.6454 - val_loss: 0.5662 - val_categorical_accuracy: 0.7199 - val_precision: 0.7715 - val_precision_1: 0.6403
# Epoch 44/44
# 349/349 [==============================] - ETA: 0s - loss: 0.6048 - categorical_accuracy: 0.6774 - precision: 0.7181 - precision_1: 0.6529lr=0.0000100
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6048 - categorical_accuracy: 0.6774 - precision: 0.7181 - precision_1: 0.6529 - val_loss: 0.5624 - val_categorical_accuracy: 0.7334 - val_precision: 0.7602 - val_precision_1: 0.6815
# Epoch 45/45
# 349/349 [==============================] - ETA: 0s - loss: 0.6089 - categorical_accuracy: 0.6698 - precision: 0.7046 - precision_1: 0.6484lr=0.0000100
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6089 - categorical_accuracy: 0.6698 - precision: 0.7046 - precision_1: 0.6484 - val_loss: 0.5627 - val_categorical_accuracy: 0.7342 - val_precision: 0.7625 - val_precision_1: 0.6805
# Epoch 46/46
# 349/349 [==============================] - ETA: 0s - loss: 0.6074 - categorical_accuracy: 0.6688 - precision: 0.7092 - precision_1: 0.6450lr=0.0000100
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6074 - categorical_accuracy: 0.6688 - precision: 0.7092 - precision_1: 0.6450 - val_loss: 0.5626 - val_categorical_accuracy: 0.7342 - val_precision: 0.7625 - val_precision_1: 0.6805
# Epoch 47/47
# 349/349 [==============================] - ETA: 0s - loss: 0.6128 - categorical_accuracy: 0.6688 - precision: 0.7033 - precision_1: 0.6475lr=0.0000100
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6128 - categorical_accuracy: 0.6688 - precision: 0.7033 - precision_1: 0.6475 - val_loss: 0.5621 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 48/48
# 349/349 [==============================] - ETA: 0s - loss: 0.6057 - categorical_accuracy: 0.6731 - precision: 0.7126 - precision_1: 0.6494lr=0.0000100
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6057 - categorical_accuracy: 0.6731 - precision: 0.7126 - precision_1: 0.6494 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 49/49
# 349/349 [==============================] - ETA: 0s - loss: 0.6156 - categorical_accuracy: 0.6582 - precision: 0.6926 - precision_1: 0.6375lr=0.0000100
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6156 - categorical_accuracy: 0.6582 - precision: 0.6926 - precision_1: 0.6375 - val_loss: 0.5625 - val_categorical_accuracy: 0.7368 - val_precision: 0.7661 - val_precision_1: 0.6819
# Epoch 50/50
# 349/349 [==============================] - ETA: 0s - loss: 0.6140 - categorical_accuracy: 0.6636 - precision: 0.7010 - precision_1: 0.6413lr=0.0000100
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6140 - categorical_accuracy: 0.6636 - precision: 0.7010 - precision_1: 0.6413 - val_loss: 0.5621 - val_categorical_accuracy: 0.7334 - val_precision: 0.7615 - val_precision_1: 0.6797
# Epoch 51/51
# 349/349 [==============================] - ETA: 0s - loss: 0.6100 - categorical_accuracy: 0.6731 - precision: 0.7080 - precision_1: 0.6514lr=0.0000100
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6100 - categorical_accuracy: 0.6731 - precision: 0.7080 - precision_1: 0.6514 - val_loss: 0.5621 - val_categorical_accuracy: 0.7334 - val_precision: 0.7615 - val_precision_1: 0.6797
# Epoch 52/52
# 349/349 [==============================] - ETA: 0s - loss: 0.6131 - categorical_accuracy: 0.6594 - precision: 0.6950 - precision_1: 0.6383lr=0.0000100
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6131 - categorical_accuracy: 0.6594 - precision: 0.6950 - precision_1: 0.6383 - val_loss: 0.5622 - val_categorical_accuracy: 0.7342 - val_precision: 0.7632 - val_precision_1: 0.6796
# Epoch 53/53
# 349/349 [==============================] - ETA: 0s - loss: 0.6120 - categorical_accuracy: 0.6657 - precision: 0.6983 - precision_1: 0.6455lr=0.0000100
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6120 - categorical_accuracy: 0.6657 - precision: 0.6983 - precision_1: 0.6455 - val_loss: 0.5625 - val_categorical_accuracy: 0.7342 - val_precision: 0.7659 - val_precision_1: 0.6762
# Epoch 54/54
# 349/349 [==============================] - ETA: 0s - loss: 0.6091 - categorical_accuracy: 0.6605 - precision: 0.6947 - precision_1: 0.6398lr=0.0000010
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6091 - categorical_accuracy: 0.6605 - precision: 0.6947 - precision_1: 0.6398 - val_loss: 0.5620 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 55/55
# 349/349 [==============================] - ETA: 0s - loss: 0.6093 - categorical_accuracy: 0.6645 - precision: 0.6983 - precision_1: 0.6437lr=0.0000010
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6093 - categorical_accuracy: 0.6645 - precision: 0.6983 - precision_1: 0.6437 - val_loss: 0.5620 - val_categorical_accuracy: 0.7334 - val_precision: 0.7615 - val_precision_1: 0.6797
# Epoch 56/56
# 349/349 [==============================] - ETA: 0s - loss: 0.6097 - categorical_accuracy: 0.6700 - precision: 0.7053 - precision_1: 0.6484lr=0.0000010
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6097 - categorical_accuracy: 0.6700 - precision: 0.7053 - precision_1: 0.6484 - val_loss: 0.5621 - val_categorical_accuracy: 0.7334 - val_precision: 0.7615 - val_precision_1: 0.6797
# Epoch 57/57
# 349/349 [==============================] - ETA: 0s - loss: 0.6103 - categorical_accuracy: 0.6702 - precision: 0.7070 - precision_1: 0.6479lr=0.0000010
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6103 - categorical_accuracy: 0.6702 - precision: 0.7070 - precision_1: 0.6479 - val_loss: 0.5621 - val_categorical_accuracy: 0.7342 - val_precision: 0.7625 - val_precision_1: 0.6805
# Epoch 58/58
# 349/349 [==============================] - ETA: 0s - loss: 0.6144 - categorical_accuracy: 0.6636 - precision: 0.6939 - precision_1: 0.6445lr=0.0000010
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6144 - categorical_accuracy: 0.6636 - precision: 0.6939 - precision_1: 0.6445 - val_loss: 0.5621 - val_categorical_accuracy: 0.7342 - val_precision: 0.7625 - val_precision_1: 0.6805
# Epoch 59/59
# 349/349 [==============================] - ETA: 0s - loss: 0.6069 - categorical_accuracy: 0.6718 - precision: 0.7059 - precision_1: 0.6506lr=0.0000001
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6069 - categorical_accuracy: 0.6718 - precision: 0.7059 - precision_1: 0.6506 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 60/60
# 349/349 [==============================] - ETA: 0s - loss: 0.6056 - categorical_accuracy: 0.6713 - precision: 0.7041 - precision_1: 0.6506lr=0.0000001
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6056 - categorical_accuracy: 0.6713 - precision: 0.7041 - precision_1: 0.6506 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 61/61
# 349/349 [==============================] - ETA: 0s - loss: 0.6137 - categorical_accuracy: 0.6650 - precision: 0.6959 - precision_1: 0.6456lr=0.0000001
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6137 - categorical_accuracy: 0.6650 - precision: 0.6959 - precision_1: 0.6456 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 62/62
# 349/349 [==============================] - ETA: 0s - loss: 0.6061 - categorical_accuracy: 0.6691 - precision: 0.7017 - precision_1: 0.6487lr=0.0000001
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6061 - categorical_accuracy: 0.6691 - precision: 0.7017 - precision_1: 0.6487 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 63/63
# 349/349 [==============================] - ETA: 0s - loss: 0.6081 - categorical_accuracy: 0.6727 - precision: 0.7066 - precision_1: 0.6515lr=0.0000001
# 349/349 [==============================] - 70s 202ms/step - loss: 0.6081 - categorical_accuracy: 0.6727 - precision: 0.7066 - precision_1: 0.6515 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 64/64
# 349/349 [==============================] - ETA: 0s - loss: 0.6133 - categorical_accuracy: 0.6580 - precision: 0.6927 - precision_1: 0.6373lr=0.0000000
# 349/349 [==============================] - 70s 202ms/step - loss: 0.6133 - categorical_accuracy: 0.6580 - precision: 0.6927 - precision_1: 0.6373 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 65/65
# 349/349 [==============================] - ETA: 0s - loss: 0.6132 - categorical_accuracy: 0.6655 - precision: 0.6971 - precision_1: 0.6458lr=0.0000000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6132 - categorical_accuracy: 0.6655 - precision: 0.6971 - precision_1: 0.6458 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 66/66
# 349/349 [==============================] - ETA: 0s - loss: 0.6070 - categorical_accuracy: 0.6738 - precision: 0.7060 - precision_1: 0.6533lr=0.0000000
# 349/349 [==============================] - 70s 201ms/step - loss: 0.6070 - categorical_accuracy: 0.6738 - precision: 0.7060 - precision_1: 0.6533 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 67/67
# 349/349 [==============================] - ETA: 0s - loss: 0.6099 - categorical_accuracy: 0.6668 - precision: 0.6946 - precision_1: 0.6488lr=0.0000000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6099 - categorical_accuracy: 0.6668 - precision: 0.6946 - precision_1: 0.6488 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 68/68
# 349/349 [==============================] - ETA: 0s - loss: 0.6128 - categorical_accuracy: 0.6664 - precision: 0.6989 - precision_1: 0.6462lr=0.0000000
# 349/349 [==============================] - 71s 204ms/step - loss: 0.6128 - categorical_accuracy: 0.6664 - precision: 0.6989 - precision_1: 0.6462 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 69/69
# 349/349 [==============================] - ETA: 0s - loss: 0.6129 - categorical_accuracy: 0.6705 - precision: 0.7036 - precision_1: 0.6499lr=0.0000000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6129 - categorical_accuracy: 0.6705 - precision: 0.7036 - precision_1: 0.6499 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 70/70
# 349/349 [==============================] - ETA: 0s - loss: 0.6083 - categorical_accuracy: 0.6695 - precision: 0.7045 - precision_1: 0.6480lr=0.0000000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6083 - categorical_accuracy: 0.6695 - precision: 0.7045 - precision_1: 0.6480 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 71/71
# 349/349 [==============================] - ETA: 0s - loss: 0.6104 - categorical_accuracy: 0.6657 - precision: 0.6998 - precision_1: 0.6448lr=0.0000000
# 349/349 [==============================] - 72s 205ms/step - loss: 0.6104 - categorical_accuracy: 0.6657 - precision: 0.6998 - precision_1: 0.6448 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 72/72
# 349/349 [==============================] - ETA: 0s - loss: 0.6083 - categorical_accuracy: 0.6716 - precision: 0.7035 - precision_1: 0.6514lr=0.0000000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6083 - categorical_accuracy: 0.6716 - precision: 0.7035 - precision_1: 0.6514 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 73/73
# 349/349 [==============================] - ETA: 0s - loss: 0.6142 - categorical_accuracy: 0.6594 - precision: 0.6908 - precision_1: 0.6401lr=0.0000000
# 349/349 [==============================] - 71s 203ms/step - loss: 0.6142 - categorical_accuracy: 0.6594 - precision: 0.6908 - precision_1: 0.6401 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 74/74
# 349/349 [==============================] - ETA: 0s - loss: 0.6079 - categorical_accuracy: 0.6705 - precision: 0.7025 - precision_1: 0.6504lr=0.0000000
# 349/349 [==============================] - 71s 202ms/step - loss: 0.6079 - categorical_accuracy: 0.6705 - precision: 0.7025 - precision_1: 0.6504 - val_loss: 0.5619 - val_categorical_accuracy: 0.7342 - val_precision: 0.7618 - val_precision_1: 0.6814
# Epoch 75/75
# 342/349 [============================>.] - ETA: 1s - loss: 0.6124 - categorical_accuracy: 0.6647 - precision: 0.6988 - precision_1: 0.6440
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 43
#      40 total_epochs=100
#      41 for i in range(total_epochs):
#      42     # print("Epoch: {}".format(i))
# ---> 43     history = model_fine.fit(train_ds_aug
#      44                         ,epochs=i+1
#      45                         ,initial_epoch=i
#      46                         ,validation_data=val_ds_aug
#      47                         ,callbacks = [PrintLR()]
#      48                         # ,verbose=0
#      49                         )
#      50     # print("Learning rate: {}".format(optimiser.lr.numpy()))
#      51     val_loss = history.history['val_loss'][-1]
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # with augment

# %%
preprocessing = preprocess_input
pre_trained = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_height,img_width,3))
pre_trained.trainable = False
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation((0,0.2),fill_mode='constant'),
  tf.keras.layers.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2),fill_mode='constant'),
  tf.keras.layers.RandomTranslation(height_factor=(-0.1,0.1),width_factor=(-0.1,0.1),fill_mode='constant')
  ])
#Define model_aug architect
tfinput = Input(shape=(img_height,img_width,3))
data_augment = data_augmentation(tfinput,training=True)
pre_process = preprocessing(data_augment)
inceptionv3_model=pre_trained(pre_process,training=False)
# flatten = tf.keras.layers.GlobalAveragePooling2D()(inceptionv3_model)
flatten = tf.keras.layers.Flatten()(inceptionv3_model)
# DO1 = Dropout(0.8)(flatten)
# x = Dense(1024,activation = 'relu')(flatten)
# x = Dense(512,activation='relu')(x)
x = Dense(8,activation = 'relu')(flatten)
x = Dense(8,activation='relu')(x)
x=Dropout(0.5)(x)
# x = Dense(512,activation='relu',kernel_regularizer=regularizers.l2(0.1))(x)
x = Dense(8,activation='relu',kernel_regularizer=regularizers.l2(0.1))(x)
# output = Dense(1, activation="sigmoid")(DO2)
output = Dense(2, activation="softmax")(x)
model_aug = Model(tfinput,output)
model_aug.summary()

model_aug.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(class_id=0),tf.keras.metrics.Precision(class_id=1)]
    # ,jit_compile=True
)
model_aug.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_categorical_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')

#Training Dense layers to initialise the categoriser before fine tuning the CNN mode
with tf.device('/GPU:0'):
    total_epochs = 10
    dense_init = model_aug.fit(train_ds_aug
                        ,epochs=total_epochs
                        ,validation_data=val_ds_aug
                        ,callbacks = [cp_callback]
                        )

# model_aug.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(dense_init.history['loss'])
plt.subplot(132)
plt.plot(dense_init.history['val_loss'])
plt.subplot(133)
plt.plot(dense_init.history['val_categorical_accuracy'])
tf.keras.backend.clear_session()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 300, 300, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 300, 300, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 8)                 16392
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 21,819,338
# Trainable params: 16,554
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 300, 300, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 300, 300, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 8)                 16392
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 21,819,338
# Trainable params: 16,554
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 1611/1612 [============================>.] - ETA: 0s - loss: 0.7785 - categorical_accuracy: 0.5568 - precision: 0.5584 - precision_1: 0.5188WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
#
# Epoch 1: val_categorical_accuracy improved from -inf to 0.60976, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint/cp-0001.ckpt
# 1612/1612 [==============================] - 111s 66ms/step - loss: 0.7785 - categorical_accuracy: 0.5568 - precision: 0.5583 - precision_1: 0.5188 - val_loss: 0.6301 - val_categorical_accuracy: 0.6098 - val_precision: 0.6098 - val_precision_1: 0.0000e+00
# Epoch 2/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6659 - categorical_accuracy: 0.6081 - precision: 0.6178 - precision_1: 0.5862
# Epoch 2: val_categorical_accuracy improved from 0.60976 to 0.67872, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint/cp-0002.ckpt
# 1612/1612 [==============================] - 104s 65ms/step - loss: 0.6659 - categorical_accuracy: 0.6081 - precision: 0.6178 - precision_1: 0.5862 - val_loss: 0.6228 - val_categorical_accuracy: 0.6787 - val_precision: 0.7340 - val_precision_1: 0.5899
# Epoch 3/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6545 - categorical_accuracy: 0.6203 - precision: 0.6505 - precision_1: 0.5781
# Epoch 3: val_categorical_accuracy did not improve from 0.67872
# 1612/1612 [==============================] - 104s 64ms/step - loss: 0.6545 - categorical_accuracy: 0.6203 - precision: 0.6505 - precision_1: 0.5781 - val_loss: 0.6236 - val_categorical_accuracy: 0.6602 - val_precision: 0.7734 - val_precision_1: 0.5498
# Epoch 4/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6513 - categorical_accuracy: 0.6236 - precision: 0.6606 - precision_1: 0.5771
# Epoch 4: val_categorical_accuracy improved from 0.67872 to 0.67956, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint/cp-0004.ckpt
# 1612/1612 [==============================] - 104s 65ms/step - loss: 0.6513 - categorical_accuracy: 0.6236 - precision: 0.6606 - precision_1: 0.5771 - val_loss: 0.6082 - val_categorical_accuracy: 0.6796 - val_precision: 0.7429 - val_precision_1: 0.5863
# Epoch 5/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6435 - categorical_accuracy: 0.6306 - precision: 0.6665 - precision_1: 0.5853
# Epoch 5: val_categorical_accuracy improved from 0.67956 to 0.69807, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint/cp-0005.ckpt
# 1612/1612 [==============================] - 104s 65ms/step - loss: 0.6435 - categorical_accuracy: 0.6306 - precision: 0.6665 - precision_1: 0.5853 - val_loss: 0.5874 - val_categorical_accuracy: 0.6981 - val_precision: 0.7440 - val_precision_1: 0.6196
# Epoch 6/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6442 - categorical_accuracy: 0.6331 - precision: 0.6784 - precision_1: 0.5824
# Epoch 6: val_categorical_accuracy did not improve from 0.69807
# 1612/1612 [==============================] - 104s 64ms/step - loss: 0.6442 - categorical_accuracy: 0.6331 - precision: 0.6784 - precision_1: 0.5824 - val_loss: 0.5959 - val_categorical_accuracy: 0.6846 - val_precision: 0.7365 - val_precision_1: 0.5991
# Epoch 7/10
# 1611/1612 [============================>.] - ETA: 0s - loss: 0.6471 - categorical_accuracy: 0.6263 - precision: 0.6716 - precision_1: 0.5755
# Epoch 7: val_categorical_accuracy did not improve from 0.69807
# 1612/1612 [==============================] - 104s 65ms/step - loss: 0.6470 - categorical_accuracy: 0.6264 - precision: 0.6715 - precision_1: 0.5756 - val_loss: 0.5975 - val_categorical_accuracy: 0.6947 - val_precision: 0.7638 - val_precision_1: 0.6004
# Epoch 8/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6455 - categorical_accuracy: 0.6352 - precision: 0.6733 - precision_1: 0.5888
# Epoch 8: val_categorical_accuracy did not improve from 0.69807
# 1612/1612 [==============================] - 106s 66ms/step - loss: 0.6455 - categorical_accuracy: 0.6352 - precision: 0.6733 - precision_1: 0.5888 - val_loss: 0.5984 - val_categorical_accuracy: 0.6955 - val_precision: 0.7665 - val_precision_1: 0.6004
# Epoch 9/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6409 - categorical_accuracy: 0.6376 - precision: 0.6781 - precision_1: 0.5897
# Epoch 9: val_categorical_accuracy did not improve from 0.69807
# 1612/1612 [==============================] - 107s 66ms/step - loss: 0.6409 - categorical_accuracy: 0.6376 - precision: 0.6781 - precision_1: 0.5897 - val_loss: 0.5944 - val_categorical_accuracy: 0.6955 - val_precision: 0.7597 - val_precision_1: 0.6041
# Epoch 10/10
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6467 - categorical_accuracy: 0.6244 - precision: 0.6668 - precision_1: 0.5749
# Epoch 10: val_categorical_accuracy did not improve from 0.69807
# 1612/1612 [==============================] - 107s 66ms/step - loss: 0.6467 - categorical_accuracy: 0.6244 - precision: 0.6668 - precision_1: 0.5749 - val_loss: 0.6088 - val_categorical_accuracy: 0.6712 - val_precision: 0.8014 - val_precision_1: 0.5575

# %%
# tf.keras.backend.clear_session()
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/dense_init_checkpoint')
model_aug.load_weights(latest)

pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:-63]:
  layer.trainable = False
init_lr = 1e-5
steps = 10000
# final_lr = 1e-6
# lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            # ,steps
                                                            # ,final_lr
                                                            # ,power=0.5)
model_aug.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_loss/cp-{epoch:04d}.ckpt"
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_acc/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_categorical_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
model_aug.compile(
    optimizer= tf.keras.optimizers.legacy.SGD(lr=0.0001),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(class_id=0),tf.keras.metrics.Precision(class_id=1)]
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5,min_lr=1e-6,verbose=1)
with tf.device('/GPU:0'):
    total_epochs=50
    history_init = model_aug.fit(train_ds_aug
                        ,epochs=total_epochs
                        # ,initial_epoch=initial_epoch
                        ,validation_data=val_ds_aug
                        ,callbacks = [cp_callback_loss,cp_callback_acc,reduce_lr]
                        )
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_categorical_accuracy'])
tf.keras.backend.clear_session()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  sequential (Sequential)     (None, 300, 300, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 300, 300, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 300, 300, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 8)                 16392
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 21,819,338
# Trainable params: 11,124,906
# Non-trainable params: 10,694,432
# _________________________________________________________________
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6381 - categorical_accuracy: 0.6407 - precision: 0.6707 - precision_1: 0.6002WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
#
# Epoch 1: val_loss improved from inf to 0.58739, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_loss/cp-0001.ckpt
#
# Epoch 1: val_categorical_accuracy improved from -inf to 0.68881, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_acc/cp-0001.ckpt
# 1612/1612 [==============================] - 122s 73ms/step - loss: 0.6381 - categorical_accuracy: 0.6407 - precision: 0.6707 - precision_1: 0.6002 - val_loss: 0.5874 - val_categorical_accuracy: 0.6888 - val_precision: 0.7383 - val_precision_1: 0.6059 - lr: 1.0000e-04
# Epoch 2/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6374 - categorical_accuracy: 0.6450 - precision: 0.6735 - precision_1: 0.6062
# Epoch 2: val_loss did not improve from 0.58739
#
# Epoch 2: val_categorical_accuracy did not improve from 0.68881
# 1612/1612 [==============================] - 119s 74ms/step - loss: 0.6374 - categorical_accuracy: 0.6450 - precision: 0.6735 - precision_1: 0.6062 - val_loss: 0.6016 - val_categorical_accuracy: 0.6754 - val_precision: 0.7686 - val_precision_1: 0.5699 - lr: 1.0000e-04
# Epoch 3/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6373 - categorical_accuracy: 0.6391 - precision: 0.6720 - precision_1: 0.5964
# Epoch 3: val_loss did not improve from 0.58739
#
# Epoch 3: val_categorical_accuracy improved from 0.68881 to 0.69218, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_acc/cp-0003.ckpt
# 1612/1612 [==============================] - 114s 71ms/step - loss: 0.6373 - categorical_accuracy: 0.6391 - precision: 0.6720 - precision_1: 0.5964 - val_loss: 0.6008 - val_categorical_accuracy: 0.6922 - val_precision: 0.7818 - val_precision_1: 0.5888 - lr: 1.0000e-04
# Epoch 4/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6335 - categorical_accuracy: 0.6459 - precision: 0.6733 - precision_1: 0.6081
# Epoch 4: val_loss did not improve from 0.58739
#
# Epoch 4: val_categorical_accuracy did not improve from 0.69218
# 1612/1612 [==============================] - 114s 70ms/step - loss: 0.6335 - categorical_accuracy: 0.6459 - precision: 0.6733 - precision_1: 0.6081 - val_loss: 0.6020 - val_categorical_accuracy: 0.6863 - val_precision: 0.7953 - val_precision_1: 0.5767 - lr: 1.0000e-04
# Epoch 5/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6283 - categorical_accuracy: 0.6529 - precision: 0.6842 - precision_1: 0.6123
# Epoch 5: val_loss did not improve from 0.58739
#
# Epoch 5: val_categorical_accuracy did not improve from 0.69218
# 1612/1612 [==============================] - 113s 70ms/step - loss: 0.6283 - categorical_accuracy: 0.6529 - precision: 0.6842 - precision_1: 0.6123 - val_loss: 0.6009 - val_categorical_accuracy: 0.6821 - val_precision: 0.7803 - val_precision_1: 0.5754 - lr: 1.0000e-04
# Epoch 6/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6308 - categorical_accuracy: 0.6534 - precision: 0.6868 - precision_1: 0.6112
# Epoch 6: val_loss did not improve from 0.58739
#
# Epoch 6: val_categorical_accuracy did not improve from 0.69218
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1612/1612 [==============================] - 113s 70ms/step - loss: 0.6308 - categorical_accuracy: 0.6534 - precision: 0.6868 - precision_1: 0.6112 - val_loss: 0.6060 - val_categorical_accuracy: 0.6863 - val_precision: 0.7953 - val_precision_1: 0.5767 - lr: 1.0000e-04
# Epoch 7/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6208 - categorical_accuracy: 0.6596 - precision: 0.6868 - precision_1: 0.6228
# Epoch 7: val_loss did not improve from 0.58739
#
# Epoch 7: val_categorical_accuracy improved from 0.69218 to 0.70227, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_acc/cp-0007.ckpt
# 1612/1612 [==============================] - 114s 71ms/step - loss: 0.6208 - categorical_accuracy: 0.6596 - precision: 0.6868 - precision_1: 0.6228 - val_loss: 0.5931 - val_categorical_accuracy: 0.7023 - val_precision: 0.7806 - val_precision_1: 0.6042 - lr: 5.0000e-05
# Epoch 8/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6262 - categorical_accuracy: 0.6614 - precision: 0.6875 - precision_1: 0.6258
# Epoch 8: val_loss improved from 0.58739 to 0.58738, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_loss/cp-0008.ckpt
#
# Epoch 8: val_categorical_accuracy improved from 0.70227 to 0.70564, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_acc/cp-0008.ckpt
# 1612/1612 [==============================] - 115s 71ms/step - loss: 0.6262 - categorical_accuracy: 0.6614 - precision: 0.6875 - precision_1: 0.6258 - val_loss: 0.5874 - val_categorical_accuracy: 0.7056 - val_precision: 0.7820 - val_precision_1: 0.6088 - lr: 5.0000e-05
# Epoch 9/50
# 1612/1612 [==============================] - ETA: 0s - loss: 0.6272 - categorical_accuracy: 0.6565 - precision: 0.6888 - precision_1: 0.6152
# Epoch 9: val_loss improved from 0.58738 to 0.58674, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm_roi_augment/fine_tuning_checkpoint_loss/cp-0009.ckpt
#
# Epoch 9: val_categorical_accuracy did not improve from 0.70564
# 1612/1612 [==============================] - 115s 71ms/step - loss: 0.6272 - categorical_accuracy: 0.6565 - precision: 0.6888 - precision_1: 0.6152 - val_loss: 0.5867 - val_categorical_accuracy: 0.6939 - val_precision: 0.7781 - val_precision_1: 0.5926 - lr: 5.0000e-05
# Epoch 10/50
#  261/1612 [===>..........................] - ETA: 1:23 - loss: 0.6241 - categorical_accuracy: 0.6533 - precision: 0.6806 - precision_1: 0.6200

# %%
with tf.GradientTape() as tape:
  last_conv_layer = model.get_layer('dense_3')
  iterate = tf.keras.models.Model([pre_trained.inputs], [model.output, last_conv_layer.output])
  model_out, last_conv_layer = iterate(x)
  class_out = model_out[:, np.argmax(model_out[0])]
  grads = tape.gradient(class_out, last_conv_layer)
  pooled_grads = tf.keras.backend.K.mean(grads, axis=(0, 1, 2))
  
heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 3
#       1 with tf.GradientTape() as tape:
#       2   last_conv_layer = model.get_layer('dense_3')
# ----> 3   iterate = tf.keras.models.Model([pre_trained.inputs], [model.output, last_conv_layer.output])
#       4   model_out, last_conv_layer = iterate(x)
#       5   class_out = model_out[:, np.argmax(model_out[0])]
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/functional.py:166, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     157     if not all(
#     158         [
#     159             functional_utils.is_input_keras_tensor(t)
#     160             for t in tf.nest.flatten(inputs)
#     161         ]
#     162     ):
#     163         inputs, outputs = functional_utils.clone_graph_nodes(
#     164             inputs, outputs
#     165         )
# --> 166 self._init_graph_network(inputs, outputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/functional.py:265, in Functional._init_graph_network(self, inputs, outputs)
#     262     self._input_coordinates.append((layer, node_index, tensor_index))
#     264 # Keep track of the network's nodes and layers.
# --> 265 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     266     self.inputs, self.outputs
#     267 )
#     268 self._network_nodes = nodes
#     269 self._nodes_by_depth = nodes_by_depth
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/functional.py:1129, in _map_graph_network(inputs, outputs)
#    1127 for x in tf.nest.flatten(node.keras_inputs):
#    1128     if id(x) not in computable_tensors:
# -> 1129         raise ValueError(
#    1130             "Graph disconnected: cannot obtain value for "
#    1131             f'tensor {x} at layer "{layer.name}". '
#    1132             "The following previous layers were accessed "
#    1133             f"without issue: {layers_with_complete_input}"
#    1134         )
#    1135 for x in tf.nest.flatten(node.outputs):
#    1136     computable_tensors.add(id(x))
#
# ValueError: Graph disconnected: cannot obtain value for tensor KerasTensor(type_spec=TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'") at layer "sequential". The following previous layers were accessed without issue: []

# %%
# Test with different optimiser
# latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNetV2_cbis_ddsm/fine_tuning_checkpoint_acc')
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_loss')
model.load_weights(latest)
init_lr = 1e-5
steps = 10000
final_lr = 1e-6
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            ,steps
                                                            ,final_lr
                                                            ,power=0.5)
model.compile(
    optimizer= tf.keras.optimizers.RMSprop(learning_rate=1e-3),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
    # ,jit_compile=True
)
checkpoint_path = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_loss_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_acc_2/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 100
history_ft_2 = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=67
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback_loss,cp_callback_acc]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (300, 300, 3) for input KerasTensor(type_spec=TensorSpec(shape=(300, 300, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 300, 300, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Model was constructed with shape (300, 300, 3) for input KerasTensor(type_spec=TensorSpec(shape=(300, 300, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 300, 300, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 140/140 [==============================] - ETA: 0s - loss: 0.5003 - binary_accuracy: 0.7632WARNING:tensorflow:Model was constructed with shape (300, 300, 3) for input KerasTensor(type_spec=TensorSpec(shape=(300, 300, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 300, 300, 3).
#
# Epoch 1: val_loss improved from inf to 0.94284, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_loss_2/cp-0001.ckpt
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.73345, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_acc_2/cp-0001.ckpt
# 140/140 [==============================] - 39s 236ms/step - loss: 0.5003 - binary_accuracy: 0.7632 - val_loss: 0.9428 - val_binary_accuracy: 0.7335
# Epoch 2/100
# 140/140 [==============================] - ETA: 0s - loss: 0.4968 - binary_accuracy: 0.7583
# Epoch 2: val_loss improved from 0.94284 to 0.75693, saving model to /home/jj/FYP/Checkpoint/InceptionV3_cbis_ddsm/fine_tuning_checkpoint_loss_2/cp-0002.ckpt
#
# Epoch 2: val_binary_accuracy did not improve from 0.73345
# 140/140 [==============================] - 32s 227ms/step - loss: 0.4968 - binary_accuracy: 0.7583 - val_loss: 0.7569 - val_binary_accuracy: 0.7156
# Epoch 3/100
# 140/140 [==============================] - ETA: 0s - loss: 0.4985 - binary_accuracy: 0.7574
# Epoch 3: val_loss did not improve from 0.75693
#
# Epoch 3: val_binary_accuracy did not improve from 0.73345
# 140/140 [==============================] - 31s 220ms/step - loss: 0.4985 - binary_accuracy: 0.7574 - val_loss: 0.7744 - val_binary_accuracy: 0.7066
# Epoch 4/100
# 140/140 [==============================] - ETA: 0s - loss: 0.4992 - binary_accuracy: 0.7614
# Epoch 4: val_loss did not improve from 0.75693
#
# Epoch 4: val_binary_accuracy did not improve from 0.73345
# 140/140 [==============================] - 31s 219ms/step - loss: 0.4992 - binary_accuracy: 0.7614 - val_loss: 0.7663 - val_binary_accuracy: 0.6977
# Epoch 5/100
# 140/140 [==============================] - ETA: 0s - loss: 0.4846 - binary_accuracy: 0.7708
# Epoch 5: val_loss did not improve from 0.75693
#
# Epoch 5: val_binary_accuracy did not improve from 0.73345
# 140/140 [==============================] - 31s 218ms/step - loss: 0.4846 - binary_accuracy: 0.7708 - val_loss: 1.4137 - val_binary_accuracy: 0.7084
# Epoch 6/100
# 140/140 [==============================] - ETA: 0s - loss: 0.4980 - binary_accuracy: 0.7645

# %%
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_ft_2.history['loss'])
plt.subplot(132)
plt.plot(history_ft_2.history['val_loss'])
plt.subplot(133)
plt.plot(history_ft_2.history['val_binary_accuracy'])

# %%
latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss')
model.load_weights(latest)
init_lr = 5e-6
steps = 1e5
final_lr = 1e-7
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay( init_lr
                                                            ,steps
                                                            ,final_lr
                                                            ,power=0.5)
pre_trained.trainable = True
for layer in pre_trained.layers:
  if isinstance(layer, tf.keras.layers.BatchNormalization):
      layer.trainable = False
for layer in pre_trained.layers[:63]:
  layer.trainable = False
model.compile(
    optimizer= tf.keras.optimizers.Adam(learning_rate = 5e-6),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.FalseNegatives()]
)
model.summary()
checkpoint_path = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_loss/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback_loss = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
checkpoint_path_2 = "/home/jj/FYP/Checkpoint/EfficientNet_ddsm/full_model_checkpoint_acc/cp-{epoch:04d}.ckpt"
cp_callback_acc = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path_2, 
    verbose=1, 
    monitor='val_binary_accuracy',
    save_best_only=True,
    save_weights_only=True,
    save_freq='epoch')
total_epochs = 100
history_init = model.fit(train_ds_aug
                    ,epochs=total_epochs
                    # ,initial_epoch=38
                    ,validation_data=val_ds_aug
                    ,callbacks = [cp_callback_loss,cp_callback_acc]
                    )
# model.save(save_dir + "inceptionv3")
plt.figure(figsize=(30,10))
plt.subplot(131)
plt.plot(history_init.history['loss'])
plt.subplot(132)
plt.plot(history_init.history['val_loss'])
plt.subplot(133)
plt.plot(history_init.history['val_binary_accuracy'])
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.engine.functional.Functional object at 0x7f27cff53430> and <keras.layers.core.tf_op_layer.TFOpLambda object at 0x7f27cff11e20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x7f27cd165370> and <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x7f27cff53c40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x7f27cd1d7e20> and <keras.layers.regularization.dropout.Dropout object at 0x7f27cd1c0940>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x7f27cd17caf0> and <keras.layers.regularization.dropout.Dropout object at 0x7f27cd1a8ee0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7c5130> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7c09d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7c09d0> and <keras.layers.core.activation.Activation object at 0x7f28700be280>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2858ff0880> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2858ff0f40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2858ff0f40> and <keras.layers.core.activation.Activation object at 0x7f284d7837c0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d78ce20> and <keras.layers.core.activation.Activation object at 0x7f284d7938b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d793610> and <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f284d796d30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d796d60> and <keras.layers.core.activation.Activation object at 0x7f284d7a3490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7a3e50> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7ac430>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7ac430> and <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f284d7acd60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7aefd0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7bf8e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7bf8e0> and <keras.layers.core.activation.Activation object at 0x7f2841fd0c10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fd06d0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7b6c70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f284d7b6c70> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fc9d00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fc9d00> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7bb790>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d7bb790> and <keras.layers.core.activation.Activation object at 0x7f284d7bbcd0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fdb640> and <keras.layers.core.activation.Activation object at 0x7f2841fdbb80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fd4430> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fe0b20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fe0b20> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d796850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f284d796850> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fe85b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fc4730> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff2a90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fe85b0> and <keras.layers.core.activation.Activation object at 0x7f2841fc4c70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff2a90> and <keras.layers.core.activation.Activation object at 0x7f2841fe8af0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f9c2b0> and <keras.layers.merging.concatenate.Concatenate object at 0x7f2841fe0160>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fa0f40> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f9c2b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f85ac0> and <keras.layers.core.activation.Activation object at 0x7f2841fa07f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f93dc0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f85ac0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841ff9e80> and <keras.layers.core.activation.Activation object at 0x7f2841fad5b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841feb6d0> and <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x7f2841ffcbe0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841f95df0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841ff9e80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fd0a60> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841feb6d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff9ac0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fd0a60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841f95fd0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff9ac0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fbb0d0> and <keras.layers.core.activation.Activation object at 0x7f2841f95610>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfd1f70> and <keras.layers.core.activation.Activation object at 0x7f2841f853d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fbb910> and <keras.layers.merging.concatenate.Concatenate object at 0x7f2841fc4520>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfc1ca0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fbb0d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fbdf10> and <keras.layers.core.activation.Activation object at 0x7f283cfd16a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfdcd00> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fbb910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fb6df0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fbdf10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfc11f0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfdcd00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfcb070> and <keras.layers.core.activation.Activation object at 0x7f283cfdcf10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfd70a0> and <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x7f283cff1a30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fbadf0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfc11f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfc3fd0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfcb070>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfe9f10> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841fbadf0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cff4be0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfc3fd0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf88a90> and <keras.layers.core.activation.Activation object at 0x7f283cfc3640>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf811f0> and <keras.layers.core.activation.Activation object at 0x7f283cfe9f40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf928e0> and <keras.layers.merging.concatenate.Concatenate object at 0x7f283cffcc70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf9d610> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf88a90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfff5b0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf811f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf92460> and <keras.layers.core.activation.Activation object at 0x7f283cf814f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfffd90> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf9d610>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfe9bb0> and <keras.layers.core.activation.Activation object at 0x7f283cf9db50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfa7d00> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfe9bb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf41610> and <keras.layers.core.activation.Activation object at 0x7f283cfff520>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfbbb80> and <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f283cffc3d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf4f580> and <keras.layers.merging.concatenate.Concatenate object at 0x7f2841fbdbb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfa3790> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf41610>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f28700cab20> and <keras.layers.core.activation.Activation object at 0x7f283cf41b50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfa3820> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf4f580>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf41f70> and <keras.layers.core.activation.Activation object at 0x7f283cf4fac0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfa4af0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf41f70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf4ff70> and <keras.layers.core.activation.Activation object at 0x7f283cfa3f10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfa53d0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfa4af0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf5fbb0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf4ff70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fdb3a0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf5fbb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfab940> and <keras.layers.core.activation.Activation object at 0x7f283cfa58e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf5f4f0> and <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x7f283cf6fd30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf4fee0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2841fdb3a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf5be20> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf74a30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cf74a30> and <keras.layers.core.activation.Activation object at 0x7f283cfa1ca0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf4ffd0> and <keras.layers.core.activation.Activation object at 0x7f283cf6f8e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff2be0> and <keras.layers.core.activation.Activation object at 0x7f283cf7f820>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfa11c0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf4ffd0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cd4370> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2841ff2be0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cce2b0> and <keras.layers.core.activation.Activation object at 0x7f2819ce6a30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819ce6970> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cce2b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf5b3d0> and <keras.layers.core.activation.Activation object at 0x7f2819cf6490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cf6520> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cf5b3d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819ce6ac0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f29007cc550>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f29007cc550> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cc59a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cc59a0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cd8850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cceee0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819c84f40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cd8850> and <keras.layers.core.activation.Activation object at 0x7f2819cc5580>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819c84f40> and <keras.layers.core.activation.Activation object at 0x7f2819c8c2e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819c8c160> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cac2e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cac2e0> and <keras.layers.core.activation.Activation object at 0x7f2819c84f10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cac820> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cd8220>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cd8220> and <keras.layers.core.activation.Activation object at 0x7f2819cec9a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cfb190> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cf69a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cf69a0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cacd60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cacd60> and <keras.layers.core.activation.Activation object at 0x7f2819ca42b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f283cfb63a0> and <keras.layers.core.activation.Activation object at 0x7f2819cc5d60>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cb5130> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819ce6cd0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f283cfe99d0> and <keras.layers.core.activation.Activation object at 0x7f280c0bd6a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f2819cb5af0> and <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x7f280c0cb880>).
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f2819cd7760> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffd5220>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c071d90> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f280c05b9a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c0b26d0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c078250>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f280c06a280> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c0b2490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffd5220> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffe3490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f280c081eb0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c078910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffe5a90> and <keras.layers.core.activation.Activation object at 0x7f27cffd5c40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f280c05b9a0> and <keras.layers.core.activation.Activation object at 0x7f280c045b80>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c078250> and <keras.layers.core.activation.Activation object at 0x7f280c053a00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c0785b0> and <keras.layers.merging.concatenate.Concatenate object at 0x7f27cfff3c40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c0b2490> and <keras.layers.core.activation.Activation object at 0x7f27cfff8f10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffe3490> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffa7fd0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cfff3d90> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffae760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c078910> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff882e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cfff8bb0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffbd4f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffa7fd0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffb50a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffae760> and <keras.layers.core.activation.Activation object at 0x7f27cff95850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff882e0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff4cb20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cffbd4f0> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff95c10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cff95790> and <keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff83d00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffb50a0> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cff94850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff95940> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cff44c40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff88070> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffb58e0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff4cb20> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cfff36d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff95c10> and <keras.layers.core.activation.Activation object at 0x7f27cff88100>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.convolutional.conv2d.Conv2D object at 0x7f27cff83d00> and <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f280c0786a0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cff94850> and <keras.layers.core.activation.Activation object at 0x7f27cff88e20>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cffa7e50> and <keras.layers.merging.concatenate.Concatenate object at 0x7f280c0f0610>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f27cff44c40> and <keras.layers.core.activation.Activation object at 0x7f280c0b4b50>).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 latest = tf.train.latest_checkpoint('/home/jj/FYP/Checkpoint/EfficientNet_ddsm/fine_tuning_checkpoint_loss')
# ----> 2 model.load_weights(latest)
#       3 init_lr = 5e-6
#       4 steps = 1e5
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/optimizers/optimizer_experimental/optimizer.py:131, in _BaseOptimizer._create_or_restore_slot_variable(self, **kwargs)
#     130 def _create_or_restore_slot_variable(self, **kwargs):
# --> 131     raise ValueError(
#     132         "You are trying to restore a checkpoint from a legacy Keras "
#     133         "optimizer into a v2.11+ Optimizer, which can cause "
#     134         "errors. Please update the optimizer referenced in your code "
#     135         "to be an instance of "
#     136         "`tf.keras.optimizers.legacy.Optimizer`, e.g.: "
#     137         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}`."
#     138     )
#
# ValueError: You are trying to restore a checkpoint from a legacy Keras optimizer into a v2.11+ Optimizer, which can cause errors. Please update the optimizer referenced in your code to be an instance of `tf.keras.optimizers.legacy.Optimizer`, e.g.: `tf.keras.optimizers.legacy.Adam`.

# %%
# for dirName, subdirList, fileList in os.walk('/mnt/c/Users/user/Desktop/CBIS-DDSM/full/'):
#     for fname in fileList:
#         if fname.endswith('.png') and dirName:
#             info = fname.split('_')
#             patient_id = info[1]+ '_' + info[2]
#             mam_type = info[0]
#             view = info[4].split('.')[0]
#             if mam_type =='Calc-Test': 
#                 x = calc_test
#                 train_test = 'test'
#             elif mam_type == 'Calc-Training': 
#                 x = calc_train
#                 train_test = 'train'
#             elif mam_type == 'Mass-Training': 
#                 x = mass_train
#                 train_test = 'train'
#             else: 
#                 x = mass_test
#                 train_test = 'test'
#             for y in x.to_numpy():
#                 if y[0] == patient_id and y[1] == info[3] and y[2] == view:
#                     if y[3] == 'MALIGNANT':
#                         add_type = 'malignant'
#                     else:
#                         add_type = 'benign'
#             shutil.move(dirName+'/'+fname,dirName+train_test+'/'+add_type+'/'+fname)
